# %% [markdown]
# # Hand-make Linear Regression

# %%
# approximate function
def predict_sales(X, w, b):
    return w*X + b

# %%
# we use MSE (L2) function as a cost function
def cost_function(X, y, w, b):
    samples = X.shape[0]
    total_error = 0.0
    for i in range(samples):
        total_error += (y[i] - (w*X[i] + b))**2
    return total_error / samples

# %%
def update_weights(X, y, w, b, learning_rate):
    w_d = 0
    b_d = 0
    samples = X.shape[0]

    for i in range(samples):
        # Calculate partial derivatives
        # -2x(y - (mx + b))
        w_d += -2*X[i] * (y[i] - (w*X[i] + b))

        # -2(y - (mx + b))
        b_d += -2*(y[i] - (w*X[i] + b))

    # We subtract because the derivatives point in direction of steepest ascent
    w -= (w_d / samples) * learning_rate
    b -= (b_d / samples) * learning_rate

    return w, b

# %%
def train(X, y, learning_rate, iters):
    cost_history = []
    w = 0
    b = 0

    for i in range(iters):
        w, b = update_weights(X, y, w, b, learning_rate)

        #Calculate cost for auditing purposes
        cost = cost_function(X, y, w, b)
        cost_history.append(cost)

        # Log Progress
        if i % 10 == 0:
            print("iter={}    weight={}    bias={}    cost={}".format(i, w, b, cost))

    return w, b, cost_history

# %% [markdown]
# ## Example

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# %matplotlib notebook

# %%
X, y = make_regression(n_samples=160, n_features=1, random_state=0, noise=1)
print(X.shape)
print(y.shape)
# print(X[:10])
# Out:
# (160, 1)
# (160,)

# %%
fig1, ax1 = plt.subplots();
ax1.scatter(X, y);
# the best coef from next cell
weight = 2.4
bias = 0
ax1.plot(X, X*weight + bias, 'r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
weight = np.arange(0, 4, 0.2)
bias = range (-3, 3)
for elem_w in weight:
    for elem_b in bias:
        # ax1.plot(X, X*elem_w + elem_b)
        print("Cost function = {:.2f} value for weight {:.1f} and bias {}".format(
            float(cost_function(X, y, elem_w, elem_b)), elem_w, elem_b))
# Out:
# Cost function = 17.07 value for weight 0.0 and bias -3
# Cost function = 11.79 value for weight 0.0 and bias -2
# Cost function = 8.52 value for weight 0.0 and bias -1
# Cost function = 7.24 value for weight 0.0 and bias 0
# Cost function = 7.97 value for weight 0.0 and bias 1
# Cost function = 10.69 value for weight 0.0 and bias 2
# Cost function = 15.96 value for weight 0.2 and bias -3
# Cost function = 10.73 value for weight 0.2 and bias -2
# Cost function = 7.49 value for weight 0.2 and bias -1
# Cost function = 6.26 value for weight 0.2 and bias 0
# Cost function = 7.03 value for weight 0.2 and bias 1
# Cost function = 9.79 value for weight 0.2 and bias 2
# Cost function = 14.93 value for weight 0.4 and bias -3
# Cost function = 9.74 value for weight 0.4 and bias -2
# Cost function = 6.55 value for weight 0.4 and bias -1
# Cost function = 5.36 value for weight 0.4 and bias 0
# Cost function = 6.17 value for weight 0.4 and bias 1
# Cost function = 8.98 value for weight 0.4 and bias 2
# Cost function = 13.99 value for weight 0.6 and bias -3
# Cost function = 8.84 value for weight 0.6 and bias -2
# Cost function = 5.69 value for weight 0.6 and bias -1
# Cost function = 4.54 value for weight 0.6 and bias 0
# Cost function = 5.39 value for weight 0.6 and bias 1
# Cost function = 8.24 value for weight 0.6 and bias 2
# Cost function = 13.14 value for weight 0.8 and bias -3
# Cost function = 8.03 value for weight 0.8 and bias -2
# Cost function = 4.92 value for weight 0.8 and bias -1
# Cost function = 3.81 value for weight 0.8 and bias 0
# Cost function = 4.70 value for weight 0.8 and bias 1
# Cost function = 7.59 value for weight 0.8 and bias 2
# Cost function = 12.36 value for weight 1.0 and bias -3
# Cost function = 7.30 value for weight 1.0 and bias -2
# Cost function = 4.23 value for weight 1.0 and bias -1
# Cost function = 3.16 value for weight 1.0 and bias 0
# Cost function = 4.09 value for weight 1.0 and bias 1
# Cost function = 7.03 value for weight 1.0 and bias 2
# Cost function = 11.67 value for weight 1.2 and bias -3
# Cost function = 6.65 value for weight 1.2 and bias -2
# Cost function = 3.62 value for weight 1.2 and bias -1
# Cost function = 2.59 value for weight 1.2 and bias 0
# Cost function = 3.57 value for weight 1.2 and bias 1
# Cost function = 6.54 value for weight 1.2 and bias 2
# Cost function = 11.07 value for weight 1.4 and bias -3
# Cost function = 6.08 value for weight 1.4 and bias -2
# Cost function = 3.10 value for weight 1.4 and bias -1
# Cost function = 2.11 value for weight 1.4 and bias 0
# Cost function = 3.13 value for weight 1.4 and bias 1
# Cost function = 6.14 value for weight 1.4 and bias 2
# Cost function = 10.54 value for weight 1.6 and bias -3
# Cost function = 5.60 value for weight 1.6 and bias -2
# Cost function = 2.66 value for weight 1.6 and bias -1
# Cost function = 1.71 value for weight 1.6 and bias 0
# Cost function = 2.77 value for weight 1.6 and bias 1
# Cost function = 5.83 value for weight 1.6 and bias 2
# Cost function = 10.10 value for weight 1.8 and bias -3
# Cost function = 5.20 value for weight 1.8 and bias -2
# Cost function = 2.30 value for weight 1.8 and bias -1
# Cost function = 1.40 value for weight 1.8 and bias 0
# Cost function = 2.50 value for weight 1.8 and bias 1
# Cost function = 5.60 value for weight 1.8 and bias 2
# Cost function = 9.75 value for weight 2.0 and bias -3
# Cost function = 4.89 value for weight 2.0 and bias -2
# Cost function = 2.03 value for weight 2.0 and bias -1
# Cost function = 1.17 value for weight 2.0 and bias 0
# Cost function = 2.31 value for weight 2.0 and bias 1
# Cost function = 5.45 value for weight 2.0 and bias 2
# Cost function = 9.47 value for weight 2.2 and bias -3
# Cost function = 4.66 value for weight 2.2 and bias -2
# Cost function = 1.84 value for weight 2.2 and bias -1
# Cost function = 1.02 value for weight 2.2 and bias 0
# Cost function = 2.20 value for weight 2.2 and bias 1
# Cost function = 5.38 value for weight 2.2 and bias 2
# Cost function = 9.29 value for weight 2.4 and bias -3
# Cost function = 4.51 value for weight 2.4 and bias -2
# Cost function = 1.73 value for weight 2.4 and bias -1
# Cost function = 0.95 value for weight 2.4 and bias 0
# Cost function = 2.18 value for weight 2.4 and bias 1
# Cost function = 5.40 value for weight 2.4 and bias 2
# Cost function = 9.18 value for weight 2.6 and bias -3
# Cost function = 4.44 value for weight 2.6 and bias -2
# Cost function = 1.71 value for weight 2.6 and bias -1
# Cost function = 0.97 value for weight 2.6 and bias 0
# Cost function = 2.24 value for weight 2.6 and bias 1
# Cost function = 5.50 value for weight 2.6 and bias 2
# Cost function = 9.16 value for weight 2.8 and bias -3
# Cost function = 4.46 value for weight 2.8 and bias -2
# Cost function = 1.77 value for weight 2.8 and bias -1
# Cost function = 1.08 value for weight 2.8 and bias 0
# Cost function = 2.38 value for weight 2.8 and bias 1
# Cost function = 5.69 value for weight 2.8 and bias 2
# Cost function = 9.22 value for weight 3.0 and bias -3
# Cost function = 4.57 value for weight 3.0 and bias -2
# Cost function = 1.91 value for weight 3.0 and bias -1
# Cost function = 1.26 value for weight 3.0 and bias 0
# Cost function = 2.61 value for weight 3.0 and bias 1
# Cost function = 5.96 value for weight 3.0 and bias 2
# Cost function = 9.37 value for weight 3.2 and bias -3
# Cost function = 4.75 value for weight 3.2 and bias -2
# Cost function = 2.14 value for weight 3.2 and bias -1
# Cost function = 1.53 value for weight 3.2 and bias 0
# Cost function = 2.92 value for weight 3.2 and bias 1
# Cost function = 6.31 value for weight 3.2 and bias 2
# Cost function = 9.59 value for weight 3.4 and bias -3
# Cost function = 5.02 value for weight 3.4 and bias -2
# Cost function = 2.45 value for weight 3.4 and bias -1
# Cost function = 1.88 value for weight 3.4 and bias 0
# Cost function = 3.31 value for weight 3.4 and bias 1
# Cost function = 6.74 value for weight 3.4 and bias 2
# Cost function = 9.91 value for weight 3.6 and bias -3
# Cost function = 5.38 value for weight 3.6 and bias -2
# Cost function = 2.85 value for weight 3.6 and bias -1
# Cost function = 2.32 value for weight 3.6 and bias 0
# Cost function = 3.79 value for weight 3.6 and bias 1
# Cost function = 7.26 value for weight 3.6 and bias 2
# Cost function = 10.30 value for weight 3.8 and bias -3
# Cost function = 5.82 value for weight 3.8 and bias -2
# Cost function = 3.33 value for weight 3.8 and bias -1
# Cost function = 2.84 value for weight 3.8 and bias 0
# Cost function = 4.35 value for weight 3.8 and bias 1
# Cost function = 7.87 value for weight 3.8 and bias 2

# %%
# split dataset into test and train set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# output setting for numpy 
np.set_printoptions(precision=3)

# init parameters
weight = 0
bias = 0
learning_rate = 0.1
num_iterates = 60

# gradient descent
for i in range(num_iterates):
    weight, bias = update_weights(X_train, y_train, weight, bias, learning_rate)
    print("Weight: {}, Bias: {}, Iteration: {}".format(weight, bias, i))
# Out:
# Weight: [0.545], Bias: [0.012], Iteration: 0
# Weight: [0.968], Bias: [0.011], Iteration: 1
# Weight: [1.297], Bias: [0.002], Iteration: 2
# Weight: [1.554], Bias: [-0.013], Iteration: 3
# Weight: [1.753], Bias: [-0.03], Iteration: 4
# Weight: [1.909], Bias: [-0.047], Iteration: 5
# Weight: [2.03], Bias: [-0.065], Iteration: 6
# Weight: [2.124], Bias: [-0.081], Iteration: 7
# Weight: [2.198], Bias: [-0.096], Iteration: 8
# Weight: [2.256], Bias: [-0.109], Iteration: 9
# Weight: [2.301], Bias: [-0.121], Iteration: 10
# Weight: [2.337], Bias: [-0.132], Iteration: 11
# Weight: [2.364], Bias: [-0.141], Iteration: 12
# Weight: [2.386], Bias: [-0.149], Iteration: 13
# Weight: [2.403], Bias: [-0.156], Iteration: 14
# Weight: [2.416], Bias: [-0.161], Iteration: 15
# Weight: [2.427], Bias: [-0.166], Iteration: 16
# Weight: [2.435], Bias: [-0.17], Iteration: 17
# Weight: [2.442], Bias: [-0.174], Iteration: 18
# Weight: [2.447], Bias: [-0.177], Iteration: 19
# Weight: [2.451], Bias: [-0.179], Iteration: 20
# Weight: [2.454], Bias: [-0.181], Iteration: 21
# Weight: [2.457], Bias: [-0.183], Iteration: 22
# Weight: [2.459], Bias: [-0.184], Iteration: 23
# Weight: [2.46], Bias: [-0.185], Iteration: 24
# Weight: [2.462], Bias: [-0.186], Iteration: 25
# Weight: [2.463], Bias: [-0.187], Iteration: 26
# Weight: [2.463], Bias: [-0.188], Iteration: 27
# Weight: [2.464], Bias: [-0.188], Iteration: 28
# Weight: [2.465], Bias: [-0.189], Iteration: 29
# Weight: [2.465], Bias: [-0.189], Iteration: 30
# Weight: [2.465], Bias: [-0.19], Iteration: 31
# Weight: [2.466], Bias: [-0.19], Iteration: 32
# Weight: [2.466], Bias: [-0.19], Iteration: 33
# Weight: [2.466], Bias: [-0.19], Iteration: 34
# Weight: [2.466], Bias: [-0.19], Iteration: 35
# Weight: [2.466], Bias: [-0.19], Iteration: 36
# Weight: [2.466], Bias: [-0.19], Iteration: 37
# Weight: [2.466], Bias: [-0.191], Iteration: 38
# Weight: [2.466], Bias: [-0.191], Iteration: 39
# Weight: [2.466], Bias: [-0.191], Iteration: 40
# Weight: [2.466], Bias: [-0.191], Iteration: 41
# Weight: [2.466], Bias: [-0.191], Iteration: 42
# Weight: [2.467], Bias: [-0.191], Iteration: 43
# Weight: [2.467], Bias: [-0.191], Iteration: 44
# Weight: [2.467], Bias: [-0.191], Iteration: 45
# Weight: [2.467], Bias: [-0.191], Iteration: 46
# Weight: [2.467], Bias: [-0.191], Iteration: 47
# Weight: [2.467], Bias: [-0.191], Iteration: 48
# Weight: [2.467], Bias: [-0.191], Iteration: 49
# Weight: [2.467], Bias: [-0.191], Iteration: 50
# Weight: [2.467], Bias: [-0.191], Iteration: 51
# Weight: [2.467], Bias: [-0.191], Iteration: 52
# Weight: [2.467], Bias: [-0.191], Iteration: 53
# Weight: [2.467], Bias: [-0.191], Iteration: 54
# Weight: [2.467], Bias: [-0.191], Iteration: 55
# Weight: [2.467], Bias: [-0.191], Iteration: 56
# Weight: [2.467], Bias: [-0.191], Iteration: 57
# Weight: [2.467], Bias: [-0.191], Iteration: 58
# Weight: [2.467], Bias: [-0.191], Iteration: 59

# %%
print(X)
print(y)
print(y.shape)
print(X.shape)
print(train(X, y, 0.1, 60))
# Out:
# [[ 0.127]
#  [ 0.676]
#  [-1.049]
#  [ 1.494]
#  [ 0.444]
#  [-0.438]
#  [-0.387]
#  [ 0.378]
#  [ 1.222]
#  [ 0.969]
#  [ 0.402]
#  [-1.536]
#  [ 0.672]
#  [ 1.951]
#  [ 1.896]
#  [ 0.122]
#  [-1.42 ]
#  [-1.147]
#  [ 1.454]
#  [ 1.23 ]
#  [-0.826]
#  [-0.672]
#  [ 0.067]
#  [ 0.707]
#  [-0.155]
#  [-0.028]
#  [-0.977]
#  [ 0.463]
#  [-0.742]
#  [ 0.4  ]
#  [ 0.864]
#  [ 0.334]
#  [ 0.729]
#  [-0.685]
#  [-1.348]
#  [ 1.944]
#  [-0.36 ]
#  [ 1.923]
#  [-1.093]
#  [ 0.614]
#  [ 1.127]
#  [-0.187]
#  [ 0.95 ]
#  [-1.071]
#  [-0.663]
#  [ 1.764]
#  [ 0.439]
#  [-0.854]
#  [-0.51 ]
#  [ 1.179]
#  [-0.208]
#  [-0.435]
#  [-0.363]
#  [ 0.376]
#  [ 0.167]
#  [-1.726]
#  [-0.414]
#  [ 0.635]
#  [-0.103]
#  [ 0.056]
#  [ 0.155]
#  [ 0.208]
#  [ 1.883]
#  [-0.636]
#  [-0.895]
#  [-1.099]
#  [-0.268]
#  [ 1.481]
#  [-0.302]
#  [-0.77 ]
#  [ 0.906]
#  [ 0.144]
#  [-0.907]
#  [ 0.979]
#  [ 0.411]
#  [-1.63 ]
#  [ 0.977]
#  [-1.173]
#  [ 0.046]
#  [ 1.533]
#  [-1.706]
#  [-1.165]
#  [-2.553]
#  [-0.402]
#  [ 1.488]
#  [ 0.944]
#  [ 0.298]
#  [ 0.802]
#  [-0.913]
#  [ 0.129]
#  [-0.068]
#  [ 0.387]
#  [ 1.117]
#  [ 0.011]
#  [ 1.202]
#  [-1.27 ]
#  [-1.614]
#  [ 2.241]
#  [ 1.713]
#  [ 1.868]
#  [ 1.326]
#  [-1.235]
#  [-0.871]
#  [ 0.177]
#  [-0.511]
#  [ 1.868]
#  [-0.098]
#  [-0.18 ]
#  [-0.348]
#  [-0.888]
#  [ 0.947]
#  [ 0.761]
#  [ 1.469]
#  [-1.08 ]
#  [-0.695]
#  [-0.861]
#  [-1.253]
#  [-0.747]
#  [-1.181]
#  [-0.151]
#  [ 1.91 ]
#  [-0.745]
#  [ 1.786]
#  [ 0.313]
#  [-1.981]
#  [ 2.27 ]
#  [ 0.428]
#  [-0.213]
#  [-0.634]
#  [ 0.052]
#  [ 0.356]
#  [-0.205]
#  [-0.674]
#  [ 0.466]
#  [-0.15 ]
#  [ 0.539]
#  [ 1.054]
#  [ 0.302]
#  [ 0.396]
#  [ 0.777]
#  [-1.316]
#  [-0.438]
#  [ 1.139]
#  [-0.813]
#  [-0.312]
#  [ 0.402]
#  [-0.403]
#  [-1.491]
#  [ 0.032]
#  [ 0.407]
#  [ 1.849]
#  [ 0.922]
#  [ 2.383]
#  [ 0.654]
#  [-1.454]
#  [ 0.577]
#  [ 0.156]
#  [ 0.901]
#  [-0.462]
#  [-0.579]]
# [ 1.552  2.236 -2.484  3.796  0.546 -1.799 -0.564  0.249  4.001  1.001
#  -0.793 -3.615  2.81   4.904  5.608  0.932 -4.334 -3.64   4.678  0.818
#  -2.558 -1.306  0.686  2.457 -1.358 -0.422 -3.542  0.884 -2.969  0.516
#   0.233  1.345  1.538 -2.454 -4.727  3.982  0.16   4.861 -2.756  1.614
#   2.061 -0.212  1.567 -0.721 -2.991  4.549  1.381 -1.25  -2.255  1.846
#  -0.242  0.044 -0.204  1.948  0.81  -7.775 -0.323  0.514  1.085 -0.491
#   0.786 -0.645  3.851 -1.621 -2.883 -2.828 -1.816  4.019 -0.504 -3.194
#   1.742  0.78  -2.189  4.228 -0.754 -3.795  1.974 -2.859  1.161  3.83
#  -3.718 -3.348 -6.206  0.434  2.732  2.182  2.479  2.922 -3.827  0.139
#  -0.554  1.088  2.261 -0.702  2.784 -3.32  -4.682  3.236  2.998  5.26
#   2.951 -1.91  -2.647 -0.905 -0.834  4.535  0.337 -1.33  -1.191 -0.929
#   2.056  1.494  2.594 -2.784 -0.885  0.976 -2.885 -3.582 -2.926  0.742
#   5.573 -3.796  5.247 -0.142 -6.894  3.839  1.877  0.389 -1.948 -1.252
#   1.889 -0.245 -1.24   2.257 -0.577  2.008  2.142  1.944  1.597  2.442
#  -3.365 -1.881  2.119 -2.431 -0.505  0.824 -2.084 -2.424 -0.407  0.233
#   5.628  3.181  5.242  0.127 -3.878  2.491  0.09   0.71  -0.766 -1.791]
# (160,)
# (160, 1)
# iter=0    weight=[0.513]    bias=[0.027]    cost=[4.885]
# iter=10    weight=[2.269]    bias=[-0.05]    cost=[0.98]
# iter=20    weight=[2.445]    bias=[-0.105]    cost=[0.938]
# iter=30    weight=[2.464]    bias=[-0.116]    cost=[0.937]
# iter=40    weight=[2.466]    bias=[-0.118]    cost=[0.937]
# iter=50    weight=[2.466]    bias=[-0.118]    cost=[0.937]
# (array([2.466]), array([-0.118]), [array([4.885]), array([3.416]), array([2.498]), array([1.923]), array([1.561]), array([1.333]), array([1.189]), array([1.098]), array([1.04]), array([1.003]), array([0.98]), array([0.965]), array([0.955]), array([0.949]), array([0.945]), array([0.942]), array([0.94]), array([0.939]), array([0.939]), array([0.938]), array([0.938]), array([0.938]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937]), array([0.937])])

# %% [markdown]
# # Use Regression on Real Data (Boston)

# %%
from sklearn.datasets import load_boston

# %%
X, y = load_boston(return_X_y = True)
X= X[:,5] # 5 corresponds to 'RM' 
X= X.reshape(-1,1) # make it 2d as for case of mutivariable
X_train, X_test, y_train, y_test=  train_test_split(X, y, random_state = 2018)
print ('X_train.shape= ',X_train.shape)
print ('y_train.shape= ',y_train.shape)
# plt.figure()
# plt.scatter(X, y);
weight, bias, cost_history = train(X_train, y_train, 0.02, 10000)

fig2, ax2 = plt.subplots();
ax2.scatter(X, y);
ax2.plot(X, X*weight + bias, 'r');
# Out:
# X_train.shape=  (379, 1)
# y_train.shape=  (379,)
# iter=0    weight=[5.743]    bias=[0.888]    cost=[268.53]
# iter=10    weight=[3.57]    bias=[0.375]    cost=[62.217]
# iter=20    weight=[3.574]    bias=[0.206]    cost=[62.056]
# iter=30    weight=[3.6]    bias=[0.041]    cost=[61.917]
# iter=40    weight=[3.626]    bias=[-0.123]    cost=[61.779]
# iter=50    weight=[3.651]    bias=[-0.286]    cost=[61.643]
# iter=60    weight=[3.677]    bias=[-0.449]    cost=[61.507]
# iter=70    weight=[3.703]    bias=[-0.61]    cost=[61.374]
# iter=80    weight=[3.728]    bias=[-0.771]    cost=[61.241]
# iter=90    weight=[3.753]    bias=[-0.931]    cost=[61.11]
# iter=100    weight=[3.778]    bias=[-1.091]    cost=[60.979]
# iter=110    weight=[3.803]    bias=[-1.249]    cost=[60.85]
# iter=120    weight=[3.828]    bias=[-1.407]    cost=[60.723]
# iter=130    weight=[3.853]    bias=[-1.564]    cost=[60.596]
# iter=140    weight=[3.878]    bias=[-1.721]    cost=[60.471]
# iter=150    weight=[3.902]    bias=[-1.876]    cost=[60.347]
# iter=160    weight=[3.927]    bias=[-2.031]    cost=[60.224]
# iter=170    weight=[3.951]    bias=[-2.185]    cost=[60.102]
# iter=180    weight=[3.975]    bias=[-2.339]    cost=[59.982]
# iter=190    weight=[3.999]    bias=[-2.491]    cost=[59.862]
# iter=200    weight=[4.023]    bias=[-2.643]    cost=[59.744]
# iter=210    weight=[4.047]    bias=[-2.795]    cost=[59.627]
# iter=220    weight=[4.071]    bias=[-2.945]    cost=[59.511]
# iter=230    weight=[4.094]    bias=[-3.095]    cost=[59.396]
# iter=240    weight=[4.118]    bias=[-3.244]    cost=[59.282]
# iter=250    weight=[4.141]    bias=[-3.392]    cost=[59.169]
# iter=260    weight=[4.164]    bias=[-3.54]    cost=[59.058]
# iter=270    weight=[4.187]    bias=[-3.687]    cost=[58.947]
# iter=280    weight=[4.211]    bias=[-3.833]    cost=[58.837]
# iter=290    weight=[4.233]    bias=[-3.979]    cost=[58.729]
# iter=300    weight=[4.256]    bias=[-4.124]    cost=[58.621]
# iter=310    weight=[4.279]    bias=[-4.268]    cost=[58.515]
# iter=320    weight=[4.302]    bias=[-4.411]    cost=[58.409]
# iter=330    weight=[4.324]    bias=[-4.554]    cost=[58.305]
# iter=340    weight=[4.347]    bias=[-4.696]    cost=[58.201]
# iter=350    weight=[4.369]    bias=[-4.838]    cost=[58.099]
# iter=360    weight=[4.391]    bias=[-4.979]    cost=[57.997]
# iter=370    weight=[4.413]    bias=[-5.119]    cost=[57.897]
# iter=380    weight=[4.435]    bias=[-5.258]    cost=[57.797]
# iter=390    weight=[4.457]    bias=[-5.397]    cost=[57.698]
# iter=400    weight=[4.479]    bias=[-5.535]    cost=[57.601]
# iter=410    weight=[4.5]    bias=[-5.673]    cost=[57.504]
# iter=420    weight=[4.522]    bias=[-5.809]    cost=[57.408]
# iter=430    weight=[4.543]    bias=[-5.945]    cost=[57.313]
# iter=440    weight=[4.565]    bias=[-6.081]    cost=[57.219]
# iter=450    weight=[4.586]    bias=[-6.216]    cost=[57.126]
# iter=460    weight=[4.607]    bias=[-6.35]    cost=[57.033]
# iter=470    weight=[4.628]    bias=[-6.484]    cost=[56.942]
# iter=480    weight=[4.649]    bias=[-6.617]    cost=[56.851]
# iter=490    weight=[4.67]    bias=[-6.749]    cost=[56.762]
# iter=500    weight=[4.691]    bias=[-6.881]    cost=[56.673]
# iter=510    weight=[4.711]    bias=[-7.012]    cost=[56.585]
# iter=520    weight=[4.732]    bias=[-7.142]    cost=[56.498]
# iter=530    weight=[4.752]    bias=[-7.272]    cost=[56.411]
# iter=540    weight=[4.773]    bias=[-7.401]    cost=[56.326]
# iter=550    weight=[4.793]    bias=[-7.53]    cost=[56.241]
# iter=560    weight=[4.813]    bias=[-7.658]    cost=[56.157]
# iter=570    weight=[4.833]    bias=[-7.785]    cost=[56.074]
# iter=580    weight=[4.853]    bias=[-7.912]    cost=[55.992]
# iter=590    weight=[4.873]    bias=[-8.038]    cost=[55.91]
# iter=600    weight=[4.893]    bias=[-8.163]    cost=[55.83]
# iter=610    weight=[4.913]    bias=[-8.288]    cost=[55.75]
# iter=620    weight=[4.932]    bias=[-8.413]    cost=[55.671]
# iter=630    weight=[4.952]    bias=[-8.536]    cost=[55.592]
# iter=640    weight=[4.971]    bias=[-8.66]    cost=[55.514]
# iter=650    weight=[4.99]    bias=[-8.782]    cost=[55.437]
# iter=660    weight=[5.01]    bias=[-8.904]    cost=[55.361]
# iter=670    weight=[5.029]    bias=[-9.026]    cost=[55.286]
# iter=680    weight=[5.048]    bias=[-9.146]    cost=[55.211]
# iter=690    weight=[5.067]    bias=[-9.267]    cost=[55.137]
# iter=700    weight=[5.086]    bias=[-9.386]    cost=[55.063]
# iter=710    weight=[5.104]    bias=[-9.506]    cost=[54.991]
# iter=720    weight=[5.123]    bias=[-9.624]    cost=[54.919]
# iter=730    weight=[5.142]    bias=[-9.742]    cost=[54.847]
# iter=740    weight=[5.16]    bias=[-9.86]    cost=[54.777]
# iter=750    weight=[5.179]    bias=[-9.976]    cost=[54.707]
# iter=760    weight=[5.197]    bias=[-10.093]    cost=[54.637]
# iter=770    weight=[5.215]    bias=[-10.208]    cost=[54.569]
# iter=780    weight=[5.233]    bias=[-10.324]    cost=[54.501]
# iter=790    weight=[5.251]    bias=[-10.438]    cost=[54.433]
# iter=800    weight=[5.269]    bias=[-10.552]    cost=[54.367]
# iter=810    weight=[5.287]    bias=[-10.666]    cost=[54.301]
# iter=820    weight=[5.305]    bias=[-10.779]    cost=[54.235]
# iter=830    weight=[5.323]    bias=[-10.892]    cost=[54.17]
# iter=840    weight=[5.341]    bias=[-11.003]    cost=[54.106]
# iter=850    weight=[5.358]    bias=[-11.115]    cost=[54.043]
# iter=860    weight=[5.376]    bias=[-11.226]    cost=[53.98]
# iter=870    weight=[5.393]    bias=[-11.336]    cost=[53.917]
# iter=880    weight=[5.41]    bias=[-11.446]    cost=[53.855]
# iter=890    weight=[5.428]    bias=[-11.555]    cost=[53.794]
# iter=900    weight=[5.445]    bias=[-11.664]    cost=[53.733]
# iter=910    weight=[5.462]    bias=[-11.772]    cost=[53.673]
# iter=920    weight=[5.479]    bias=[-11.88]    cost=[53.614]
# iter=930    weight=[5.496]    bias=[-11.987]    cost=[53.555]
# iter=940    weight=[5.512]    bias=[-12.094]    cost=[53.497]
# iter=950    weight=[5.529]    bias=[-12.2]    cost=[53.439]
# iter=960    weight=[5.546]    bias=[-12.306]    cost=[53.382]
# iter=970    weight=[5.562]    bias=[-12.411]    cost=[53.325]
# iter=980    weight=[5.579]    bias=[-12.516]    cost=[53.269]
# iter=990    weight=[5.595]    bias=[-12.62]    cost=[53.213]
# iter=1000    weight=[5.612]    bias=[-12.724]    cost=[53.158]
# iter=1010    weight=[5.628]    bias=[-12.827]    cost=[53.103]
# iter=1020    weight=[5.644]    bias=[-12.93]    cost=[53.049]
# iter=1030    weight=[5.66]    bias=[-13.032]    cost=[52.996]
# iter=1040    weight=[5.676]    bias=[-13.134]    cost=[52.943]
# iter=1050    weight=[5.692]    bias=[-13.235]    cost=[52.89]
# iter=1060    weight=[5.708]    bias=[-13.336]    cost=[52.838]
# iter=1070    weight=[5.724]    bias=[-13.436]    cost=[52.787]
# iter=1080    weight=[5.74]    bias=[-13.536]    cost=[52.735]
# iter=1090    weight=[5.755]    bias=[-13.635]    cost=[52.685]
# iter=1100    weight=[5.771]    bias=[-13.734]    cost=[52.635]
# iter=1110    weight=[5.786]    bias=[-13.833]    cost=[52.585]
# iter=1120    weight=[5.802]    bias=[-13.931]    cost=[52.536]
# iter=1130    weight=[5.817]    bias=[-14.028]    cost=[52.487]
# iter=1140    weight=[5.833]    bias=[-14.125]    cost=[52.439]
# iter=1150    weight=[5.848]    bias=[-14.222]    cost=[52.391]
# iter=1160    weight=[5.863]    bias=[-14.318]    cost=[52.344]
# iter=1170    weight=[5.878]    bias=[-14.413]    cost=[52.297]
# iter=1180    weight=[5.893]    bias=[-14.509]    cost=[52.251]
# iter=1190    weight=[5.908]    bias=[-14.603]    cost=[52.205]
# iter=1200    weight=[5.923]    bias=[-14.698]    cost=[52.159]
# iter=1210    weight=[5.938]    bias=[-14.791]    cost=[52.114]
# iter=1220    weight=[5.952]    bias=[-14.885]    cost=[52.07]
# iter=1230    weight=[5.967]    bias=[-14.978]    cost=[52.025]
# iter=1240    weight=[5.981]    bias=[-15.07]    cost=[51.981]
# iter=1250    weight=[5.996]    bias=[-15.162]    cost=[51.938]
# iter=1260    weight=[6.01]    bias=[-15.254]    cost=[51.895]
# iter=1270    weight=[6.025]    bias=[-15.345]    cost=[51.852]
# iter=1280    weight=[6.039]    bias=[-15.436]    cost=[51.81]
# iter=1290    weight=[6.053]    bias=[-15.526]    cost=[51.768]
# iter=1300    weight=[6.068]    bias=[-15.616]    cost=[51.727]
# iter=1310    weight=[6.082]    bias=[-15.706]    cost=[51.686]
# iter=1320    weight=[6.096]    bias=[-15.795]    cost=[51.646]
# iter=1330    weight=[6.11]    bias=[-15.883]    cost=[51.605]
# iter=1340    weight=[6.124]    bias=[-15.971]    cost=[51.565]
# iter=1350    weight=[6.137]    bias=[-16.059]    cost=[51.526]
# iter=1360    weight=[6.151]    bias=[-16.146]    cost=[51.487]
# iter=1370    weight=[6.165]    bias=[-16.233]    cost=[51.448]
# iter=1380    weight=[6.178]    bias=[-16.32]    cost=[51.41]
# iter=1390    weight=[6.192]    bias=[-16.406]    cost=[51.372]
# iter=1400    weight=[6.206]    bias=[-16.492]    cost=[51.334]
# iter=1410    weight=[6.219]    bias=[-16.577]    cost=[51.297]
# iter=1420    weight=[6.232]    bias=[-16.662]    cost=[51.26]
# iter=1430    weight=[6.246]    bias=[-16.746]    cost=[51.224]
# iter=1440    weight=[6.259]    bias=[-16.83]    cost=[51.187]
# iter=1450    weight=[6.272]    bias=[-16.914]    cost=[51.151]
# iter=1460    weight=[6.285]    bias=[-16.997]    cost=[51.116]
# iter=1470    weight=[6.298]    bias=[-17.08]    cost=[51.081]
# iter=1480    weight=[6.311]    bias=[-17.163]    cost=[51.046]
# iter=1490    weight=[6.324]    bias=[-17.245]    cost=[51.011]
# iter=1500    weight=[6.337]    bias=[-17.326]    cost=[50.977]
# iter=1510    weight=[6.35]    bias=[-17.408]    cost=[50.943]
# iter=1520    weight=[6.363]    bias=[-17.489]    cost=[50.91]
# iter=1530    weight=[6.375]    bias=[-17.569]    cost=[50.877]
# iter=1540    weight=[6.388]    bias=[-17.649]    cost=[50.844]
# iter=1550    weight=[6.401]    bias=[-17.729]    cost=[50.811]
# iter=1560    weight=[6.413]    bias=[-17.809]    cost=[50.779]
# iter=1570    weight=[6.426]    bias=[-17.888]    cost=[50.747]
# iter=1580    weight=[6.438]    bias=[-17.966]    cost=[50.715]
# iter=1590    weight=[6.45]    bias=[-18.044]    cost=[50.684]
# iter=1600    weight=[6.463]    bias=[-18.122]    cost=[50.653]
# iter=1610    weight=[6.475]    bias=[-18.2]    cost=[50.622]
# iter=1620    weight=[6.487]    bias=[-18.277]    cost=[50.591]
# iter=1630    weight=[6.499]    bias=[-18.354]    cost=[50.561]
# iter=1640    weight=[6.511]    bias=[-18.43]    cost=[50.531]
# iter=1650    weight=[6.523]    bias=[-18.506]    cost=[50.502]
# iter=1660    weight=[6.535]    bias=[-18.582]    cost=[50.472]
# iter=1670    weight=[6.547]    bias=[-18.657]    cost=[50.443]
# iter=1680    weight=[6.559]    bias=[-18.732]    cost=[50.414]
# iter=1690    weight=[6.57]    bias=[-18.807]    cost=[50.386]
# iter=1700    weight=[6.582]    bias=[-18.881]    cost=[50.358]
# iter=1710    weight=[6.594]    bias=[-18.955]    cost=[50.33]
# iter=1720    weight=[6.605]    bias=[-19.029]    cost=[50.302]
# iter=1730    weight=[6.617]    bias=[-19.102]    cost=[50.274]
# iter=1740    weight=[6.628]    bias=[-19.175]    cost=[50.247]
# iter=1750    weight=[6.64]    bias=[-19.247]    cost=[50.22]
# iter=1760    weight=[6.651]    bias=[-19.319]    cost=[50.194]
# iter=1770    weight=[6.662]    bias=[-19.391]    cost=[50.167]
# iter=1780    weight=[6.674]    bias=[-19.463]    cost=[50.141]
# iter=1790    weight=[6.685]    bias=[-19.534]    cost=[50.115]
# iter=1800    weight=[6.696]    bias=[-19.605]    cost=[50.089]
# iter=1810    weight=[6.707]    bias=[-19.675]    cost=[50.064]
# iter=1820    weight=[6.718]    bias=[-19.745]    cost=[50.039]
# iter=1830    weight=[6.729]    bias=[-19.815]    cost=[50.014]
# iter=1840    weight=[6.74]    bias=[-19.884]    cost=[49.989]
# iter=1850    weight=[6.751]    bias=[-19.953]    cost=[49.965]
# iter=1860    weight=[6.762]    bias=[-20.022]    cost=[49.94]
# iter=1870    weight=[6.773]    bias=[-20.091]    cost=[49.916]
# iter=1880    weight=[6.783]    bias=[-20.159]    cost=[49.893]
# iter=1890    weight=[6.794]    bias=[-20.227]    cost=[49.869]
# iter=1900    weight=[6.805]    bias=[-20.294]    cost=[49.846]
# iter=1910    weight=[6.815]    bias=[-20.361]    cost=[49.823]
# iter=1920    weight=[6.826]    bias=[-20.428]    cost=[49.8]
# iter=1930    weight=[6.836]    bias=[-20.495]    cost=[49.777]
# iter=1940    weight=[6.847]    bias=[-20.561]    cost=[49.755]
# iter=1950    weight=[6.857]    bias=[-20.627]    cost=[49.732]
# iter=1960    weight=[6.868]    bias=[-20.692]    cost=[49.71]
# iter=1970    weight=[6.878]    bias=[-20.758]    cost=[49.688]
# iter=1980    weight=[6.888]    bias=[-20.823]    cost=[49.667]
# iter=1990    weight=[6.898]    bias=[-20.887]    cost=[49.645]
# iter=2000    weight=[6.908]    bias=[-20.952]    cost=[49.624]
# iter=2010    weight=[6.919]    bias=[-21.016]    cost=[49.603]
# iter=2020    weight=[6.929]    bias=[-21.08]    cost=[49.582]
# iter=2030    weight=[6.939]    bias=[-21.143]    cost=[49.562]
# iter=2040    weight=[6.949]    bias=[-21.206]    cost=[49.541]
# iter=2050    weight=[6.958]    bias=[-21.269]    cost=[49.521]
# iter=2060    weight=[6.968]    bias=[-21.331]    cost=[49.501]
# iter=2070    weight=[6.978]    bias=[-21.394]    cost=[49.481]
# iter=2080    weight=[6.988]    bias=[-21.456]    cost=[49.462]
# iter=2090    weight=[6.998]    bias=[-21.517]    cost=[49.442]
# iter=2100    weight=[7.007]    bias=[-21.579]    cost=[49.423]
# iter=2110    weight=[7.017]    bias=[-21.64]    cost=[49.404]
# iter=2120    weight=[7.026]    bias=[-21.7]    cost=[49.385]
# iter=2130    weight=[7.036]    bias=[-21.761]    cost=[49.366]
# iter=2140    weight=[7.045]    bias=[-21.821]    cost=[49.348]
# iter=2150    weight=[7.055]    bias=[-21.881]    cost=[49.329]
# iter=2160    weight=[7.064]    bias=[-21.941]    cost=[49.311]
# iter=2170    weight=[7.074]    bias=[-22.]    cost=[49.293]
# iter=2180    weight=[7.083]    bias=[-22.059]    cost=[49.275]
# iter=2190    weight=[7.092]    bias=[-22.118]    cost=[49.257]
# iter=2200    weight=[7.101]    bias=[-22.176]    cost=[49.24]
# iter=2210    weight=[7.111]    bias=[-22.235]    cost=[49.222]
# iter=2220    weight=[7.12]    bias=[-22.292]    cost=[49.205]
# iter=2230    weight=[7.129]    bias=[-22.35]    cost=[49.188]
# iter=2240    weight=[7.138]    bias=[-22.407]    cost=[49.171]
# iter=2250    weight=[7.147]    bias=[-22.465]    cost=[49.155]
# iter=2260    weight=[7.156]    bias=[-22.521]    cost=[49.138]
# iter=2270    weight=[7.165]    bias=[-22.578]    cost=[49.122]
# iter=2280    weight=[7.174]    bias=[-22.634]    cost=[49.105]
# iter=2290    weight=[7.182]    bias=[-22.69]    cost=[49.089]
# iter=2300    weight=[7.191]    bias=[-22.746]    cost=[49.073]
# iter=2310    weight=[7.2]    bias=[-22.802]    cost=[49.058]
# iter=2320    weight=[7.209]    bias=[-22.857]    cost=[49.042]
# iter=2330    weight=[7.217]    bias=[-22.912]    cost=[49.027]
# iter=2340    weight=[7.226]    bias=[-22.967]    cost=[49.011]
# iter=2350    weight=[7.235]    bias=[-23.021]    cost=[48.996]
# iter=2360    weight=[7.243]    bias=[-23.075]    cost=[48.981]
# iter=2370    weight=[7.252]    bias=[-23.129]    cost=[48.966]
# iter=2380    weight=[7.26]    bias=[-23.183]    cost=[48.951]
# iter=2390    weight=[7.268]    bias=[-23.236]    cost=[48.937]
# iter=2400    weight=[7.277]    bias=[-23.289]    cost=[48.922]
# iter=2410    weight=[7.285]    bias=[-23.342]    cost=[48.908]
# iter=2420    weight=[7.293]    bias=[-23.395]    cost=[48.894]
# iter=2430    weight=[7.302]    bias=[-23.447]    cost=[48.88]
# iter=2440    weight=[7.31]    bias=[-23.499]    cost=[48.866]
# iter=2450    weight=[7.318]    bias=[-23.551]    cost=[48.852]
# iter=2460    weight=[7.326]    bias=[-23.603]    cost=[48.838]
# iter=2470    weight=[7.334]    bias=[-23.654]    cost=[48.825]
# iter=2480    weight=[7.342]    bias=[-23.706]    cost=[48.811]
# iter=2490    weight=[7.35]    bias=[-23.757]    cost=[48.798]
# iter=2500    weight=[7.358]    bias=[-23.807]    cost=[48.785]
# iter=2510    weight=[7.366]    bias=[-23.858]    cost=[48.772]
# iter=2520    weight=[7.374]    bias=[-23.908]    cost=[48.759]
# iter=2530    weight=[7.382]    bias=[-23.958]    cost=[48.746]
# iter=2540    weight=[7.39]    bias=[-24.008]    cost=[48.733]
# iter=2550    weight=[7.398]    bias=[-24.057]    cost=[48.721]
# iter=2560    weight=[7.406]    bias=[-24.106]    cost=[48.708]
# iter=2570    weight=[7.413]    bias=[-24.155]    cost=[48.696]
# iter=2580    weight=[7.421]    bias=[-24.204]    cost=[48.684]
# iter=2590    weight=[7.429]    bias=[-24.253]    cost=[48.672]
# iter=2600    weight=[7.436]    bias=[-24.301]    cost=[48.66]
# iter=2610    weight=[7.444]    bias=[-24.349]    cost=[48.648]
# iter=2620    weight=[7.451]    bias=[-24.397]    cost=[48.636]
# iter=2630    weight=[7.459]    bias=[-24.445]    cost=[48.625]
# iter=2640    weight=[7.466]    bias=[-24.492]    cost=[48.613]
# iter=2650    weight=[7.474]    bias=[-24.539]    cost=[48.602]
# iter=2660    weight=[7.481]    bias=[-24.586]    cost=[48.59]
# iter=2670    weight=[7.489]    bias=[-24.633]    cost=[48.579]
# iter=2680    weight=[7.496]    bias=[-24.679]    cost=[48.568]
# iter=2690    weight=[7.503]    bias=[-24.726]    cost=[48.557]
# iter=2700    weight=[7.51]    bias=[-24.772]    cost=[48.546]
# iter=2710    weight=[7.518]    bias=[-24.818]    cost=[48.536]
# iter=2720    weight=[7.525]    bias=[-24.863]    cost=[48.525]
# iter=2730    weight=[7.532]    bias=[-24.909]    cost=[48.514]
# iter=2740    weight=[7.539]    bias=[-24.954]    cost=[48.504]
# iter=2750    weight=[7.546]    bias=[-24.999]    cost=[48.493]
# iter=2760    weight=[7.553]    bias=[-25.044]    cost=[48.483]
# iter=2770    weight=[7.56]    bias=[-25.088]    cost=[48.473]
# iter=2780    weight=[7.567]    bias=[-25.133]    cost=[48.463]
# iter=2790    weight=[7.574]    bias=[-25.177]    cost=[48.453]
# iter=2800    weight=[7.581]    bias=[-25.221]    cost=[48.443]
# iter=2810    weight=[7.588]    bias=[-25.264]    cost=[48.433]
# iter=2820    weight=[7.595]    bias=[-25.308]    cost=[48.424]
# iter=2830    weight=[7.602]    bias=[-25.351]    cost=[48.414]
# iter=2840    weight=[7.609]    bias=[-25.394]    cost=[48.404]
# iter=2850    weight=[7.615]    bias=[-25.437]    cost=[48.395]
# iter=2860    weight=[7.622]    bias=[-25.48]    cost=[48.386]
# iter=2870    weight=[7.629]    bias=[-25.522]    cost=[48.376]
# iter=2880    weight=[7.635]    bias=[-25.565]    cost=[48.367]
# iter=2890    weight=[7.642]    bias=[-25.607]    cost=[48.358]
# iter=2900    weight=[7.649]    bias=[-25.649]    cost=[48.349]
# iter=2910    weight=[7.655]    bias=[-25.69]    cost=[48.34]
# iter=2920    weight=[7.662]    bias=[-25.732]    cost=[48.332]
# iter=2930    weight=[7.668]    bias=[-25.773]    cost=[48.323]
# iter=2940    weight=[7.675]    bias=[-25.814]    cost=[48.314]
# iter=2950    weight=[7.681]    bias=[-25.855]    cost=[48.306]
# iter=2960    weight=[7.688]    bias=[-25.896]    cost=[48.297]
# iter=2970    weight=[7.694]    bias=[-25.936]    cost=[48.289]
# iter=2980    weight=[7.7]    bias=[-25.976]    cost=[48.28]
# iter=2990    weight=[7.707]    bias=[-26.017]    cost=[48.272]
# iter=3000    weight=[7.713]    bias=[-26.056]    cost=[48.264]
# iter=3010    weight=[7.719]    bias=[-26.096]    cost=[48.256]
# iter=3020    weight=[7.725]    bias=[-26.136]    cost=[48.248]
# iter=3030    weight=[7.732]    bias=[-26.175]    cost=[48.24]
# iter=3040    weight=[7.738]    bias=[-26.214]    cost=[48.232]
# iter=3050    weight=[7.744]    bias=[-26.253]    cost=[48.224]
# iter=3060    weight=[7.75]    bias=[-26.292]    cost=[48.217]
# iter=3070    weight=[7.756]    bias=[-26.331]    cost=[48.209]
# iter=3080    weight=[7.762]    bias=[-26.369]    cost=[48.201]
# iter=3090    weight=[7.768]    bias=[-26.407]    cost=[48.194]
# iter=3100    weight=[7.774]    bias=[-26.445]    cost=[48.186]
# iter=3110    weight=[7.78]    bias=[-26.483]    cost=[48.179]
# iter=3120    weight=[7.786]    bias=[-26.521]    cost=[48.172]
# iter=3130    weight=[7.792]    bias=[-26.558]    cost=[48.165]
# iter=3140    weight=[7.798]    bias=[-26.596]    cost=[48.158]
# iter=3150    weight=[7.804]    bias=[-26.633]    cost=[48.15]
# iter=3160    weight=[7.81]    bias=[-26.67]    cost=[48.143]
# iter=3170    weight=[7.815]    bias=[-26.707]    cost=[48.136]
# iter=3180    weight=[7.821]    bias=[-26.743]    cost=[48.13]
# iter=3190    weight=[7.827]    bias=[-26.78]    cost=[48.123]
# iter=3200    weight=[7.833]    bias=[-26.816]    cost=[48.116]
# iter=3210    weight=[7.838]    bias=[-26.852]    cost=[48.109]
# iter=3220    weight=[7.844]    bias=[-26.888]    cost=[48.103]
# iter=3230    weight=[7.85]    bias=[-26.924]    cost=[48.096]
# iter=3240    weight=[7.855]    bias=[-26.96]    cost=[48.09]
# iter=3250    weight=[7.861]    bias=[-26.995]    cost=[48.083]
# iter=3260    weight=[7.866]    bias=[-27.03]    cost=[48.077]
# iter=3270    weight=[7.872]    bias=[-27.065]    cost=[48.071]
# iter=3280    weight=[7.877]    bias=[-27.1]    cost=[48.064]
# iter=3290    weight=[7.883]    bias=[-27.135]    cost=[48.058]
# iter=3300    weight=[7.888]    bias=[-27.17]    cost=[48.052]
# iter=3310    weight=[7.894]    bias=[-27.204]    cost=[48.046]
# iter=3320    weight=[7.899]    bias=[-27.238]    cost=[48.04]
# iter=3330    weight=[7.905]    bias=[-27.273]    cost=[48.034]
# iter=3340    weight=[7.91]    bias=[-27.306]    cost=[48.028]
# iter=3350    weight=[7.915]    bias=[-27.34]    cost=[48.022]
# iter=3360    weight=[7.921]    bias=[-27.374]    cost=[48.016]
# iter=3370    weight=[7.926]    bias=[-27.407]    cost=[48.011]
# iter=3380    weight=[7.931]    bias=[-27.441]    cost=[48.005]
# iter=3390    weight=[7.936]    bias=[-27.474]    cost=[47.999]
# iter=3400    weight=[7.942]    bias=[-27.507]    cost=[47.994]
# iter=3410    weight=[7.947]    bias=[-27.54]    cost=[47.988]
# iter=3420    weight=[7.952]    bias=[-27.572]    cost=[47.983]
# iter=3430    weight=[7.957]    bias=[-27.605]    cost=[47.977]
# iter=3440    weight=[7.962]    bias=[-27.637]    cost=[47.972]
# iter=3450    weight=[7.967]    bias=[-27.669]    cost=[47.967]
# iter=3460    weight=[7.972]    bias=[-27.701]    cost=[47.961]
# iter=3470    weight=[7.977]    bias=[-27.733]    cost=[47.956]
# iter=3480    weight=[7.982]    bias=[-27.765]    cost=[47.951]
# iter=3490    weight=[7.987]    bias=[-27.797]    cost=[47.946]
# iter=3500    weight=[7.992]    bias=[-27.828]    cost=[47.941]
# iter=3510    weight=[7.997]    bias=[-27.859]    cost=[47.936]
# iter=3520    weight=[8.002]    bias=[-27.891]    cost=[47.931]
# iter=3530    weight=[8.007]    bias=[-27.922]    cost=[47.926]
# iter=3540    weight=[8.012]    bias=[-27.952]    cost=[47.921]
# iter=3550    weight=[8.017]    bias=[-27.983]    cost=[47.916]
# iter=3560    weight=[8.021]    bias=[-28.014]    cost=[47.911]
# iter=3570    weight=[8.026]    bias=[-28.044]    cost=[47.907]
# iter=3580    weight=[8.031]    bias=[-28.074]    cost=[47.902]
# iter=3590    weight=[8.036]    bias=[-28.104]    cost=[47.897]
# iter=3600    weight=[8.04]    bias=[-28.134]    cost=[47.893]
# iter=3610    weight=[8.045]    bias=[-28.164]    cost=[47.888]
# iter=3620    weight=[8.05]    bias=[-28.194]    cost=[47.884]
# iter=3630    weight=[8.054]    bias=[-28.224]    cost=[47.879]
# iter=3640    weight=[8.059]    bias=[-28.253]    cost=[47.875]
# iter=3650    weight=[8.064]    bias=[-28.282]    cost=[47.87]
# iter=3660    weight=[8.068]    bias=[-28.311]    cost=[47.866]
# iter=3670    weight=[8.073]    bias=[-28.34]    cost=[47.862]
# iter=3680    weight=[8.077]    bias=[-28.369]    cost=[47.858]
# iter=3690    weight=[8.082]    bias=[-28.398]    cost=[47.853]
# iter=3700    weight=[8.086]    bias=[-28.426]    cost=[47.849]
# iter=3710    weight=[8.091]    bias=[-28.455]    cost=[47.845]
# iter=3720    weight=[8.095]    bias=[-28.483]    cost=[47.841]
# iter=3730    weight=[8.1]    bias=[-28.511]    cost=[47.837]
# iter=3740    weight=[8.104]    bias=[-28.539]    cost=[47.833]
# iter=3750    weight=[8.109]    bias=[-28.567]    cost=[47.829]
# iter=3760    weight=[8.113]    bias=[-28.595]    cost=[47.825]
# iter=3770    weight=[8.117]    bias=[-28.623]    cost=[47.821]
# iter=3780    weight=[8.122]    bias=[-28.65]    cost=[47.817]
# iter=3790    weight=[8.126]    bias=[-28.678]    cost=[47.813]
# iter=3800    weight=[8.13]    bias=[-28.705]    cost=[47.809]
# iter=3810    weight=[8.135]    bias=[-28.732]    cost=[47.806]
# iter=3820    weight=[8.139]    bias=[-28.759]    cost=[47.802]
# iter=3830    weight=[8.143]    bias=[-28.786]    cost=[47.798]
# iter=3840    weight=[8.147]    bias=[-28.813]    cost=[47.795]
# iter=3850    weight=[8.152]    bias=[-28.839]    cost=[47.791]
# iter=3860    weight=[8.156]    bias=[-28.866]    cost=[47.787]
# iter=3870    weight=[8.16]    bias=[-28.892]    cost=[47.784]
# iter=3880    weight=[8.164]    bias=[-28.918]    cost=[47.78]
# iter=3890    weight=[8.168]    bias=[-28.944]    cost=[47.777]
# iter=3900    weight=[8.172]    bias=[-28.97]    cost=[47.773]
# iter=3910    weight=[8.176]    bias=[-28.996]    cost=[47.77]
# iter=3920    weight=[8.18]    bias=[-29.022]    cost=[47.766]
# iter=3930    weight=[8.184]    bias=[-29.048]    cost=[47.763]
# iter=3940    weight=[8.188]    bias=[-29.073]    cost=[47.76]
# iter=3950    weight=[8.192]    bias=[-29.098]    cost=[47.756]
# iter=3960    weight=[8.196]    bias=[-29.124]    cost=[47.753]
# iter=3970    weight=[8.2]    bias=[-29.149]    cost=[47.75]
# iter=3980    weight=[8.204]    bias=[-29.174]    cost=[47.747]
# iter=3990    weight=[8.208]    bias=[-29.199]    cost=[47.744]
# iter=4000    weight=[8.212]    bias=[-29.224]    cost=[47.74]
# iter=4010    weight=[8.216]    bias=[-29.248]    cost=[47.737]
# iter=4020    weight=[8.22]    bias=[-29.273]    cost=[47.734]
# iter=4030    weight=[8.224]    bias=[-29.297]    cost=[47.731]
# iter=4040    weight=[8.227]    bias=[-29.321]    cost=[47.728]
# iter=4050    weight=[8.231]    bias=[-29.346]    cost=[47.725]
# iter=4060    weight=[8.235]    bias=[-29.37]    cost=[47.722]
# iter=4070    weight=[8.239]    bias=[-29.394]    cost=[47.719]
# iter=4080    weight=[8.243]    bias=[-29.417]    cost=[47.716]
# iter=4090    weight=[8.246]    bias=[-29.441]    cost=[47.713]
# iter=4100    weight=[8.25]    bias=[-29.465]    cost=[47.711]
# iter=4110    weight=[8.254]    bias=[-29.488]    cost=[47.708]
# iter=4120    weight=[8.257]    bias=[-29.512]    cost=[47.705]
# iter=4130    weight=[8.261]    bias=[-29.535]    cost=[47.702]
# iter=4140    weight=[8.265]    bias=[-29.558]    cost=[47.699]
# iter=4150    weight=[8.268]    bias=[-29.581]    cost=[47.697]
# iter=4160    weight=[8.272]    bias=[-29.604]    cost=[47.694]
# iter=4170    weight=[8.276]    bias=[-29.627]    cost=[47.691]
# iter=4180    weight=[8.279]    bias=[-29.65]    cost=[47.689]
# iter=4190    weight=[8.283]    bias=[-29.672]    cost=[47.686]
# iter=4200    weight=[8.286]    bias=[-29.695]    cost=[47.683]
# iter=4210    weight=[8.29]    bias=[-29.717]    cost=[47.681]
# iter=4220    weight=[8.293]    bias=[-29.74]    cost=[47.678]
# iter=4230    weight=[8.297]    bias=[-29.762]    cost=[47.676]
# iter=4240    weight=[8.3]    bias=[-29.784]    cost=[47.673]
# iter=4250    weight=[8.304]    bias=[-29.806]    cost=[47.671]
# iter=4260    weight=[8.307]    bias=[-29.828]    cost=[47.668]
# iter=4270    weight=[8.311]    bias=[-29.849]    cost=[47.666]
# iter=4280    weight=[8.314]    bias=[-29.871]    cost=[47.664]
# iter=4290    weight=[8.318]    bias=[-29.893]    cost=[47.661]
# iter=4300    weight=[8.321]    bias=[-29.914]    cost=[47.659]
# iter=4310    weight=[8.324]    bias=[-29.936]    cost=[47.657]
# iter=4320    weight=[8.328]    bias=[-29.957]    cost=[47.654]
# iter=4330    weight=[8.331]    bias=[-29.978]    cost=[47.652]
# iter=4340    weight=[8.334]    bias=[-29.999]    cost=[47.65]
# iter=4350    weight=[8.338]    bias=[-30.02]    cost=[47.647]
# iter=4360    weight=[8.341]    bias=[-30.041]    cost=[47.645]
# iter=4370    weight=[8.344]    bias=[-30.062]    cost=[47.643]
# iter=4380    weight=[8.347]    bias=[-30.082]    cost=[47.641]
# iter=4390    weight=[8.351]    bias=[-30.103]    cost=[47.639]
# iter=4400    weight=[8.354]    bias=[-30.123]    cost=[47.636]
# iter=4410    weight=[8.357]    bias=[-30.144]    cost=[47.634]
# iter=4420    weight=[8.36]    bias=[-30.164]    cost=[47.632]
# iter=4430    weight=[8.363]    bias=[-30.184]    cost=[47.63]
# iter=4440    weight=[8.367]    bias=[-30.204]    cost=[47.628]
# iter=4450    weight=[8.37]    bias=[-30.224]    cost=[47.626]
# iter=4460    weight=[8.373]    bias=[-30.244]    cost=[47.624]
# iter=4470    weight=[8.376]    bias=[-30.264]    cost=[47.622]
# iter=4480    weight=[8.379]    bias=[-30.284]    cost=[47.62]
# iter=4490    weight=[8.382]    bias=[-30.303]    cost=[47.618]
# iter=4500    weight=[8.385]    bias=[-30.323]    cost=[47.616]
# iter=4510    weight=[8.388]    bias=[-30.342]    cost=[47.614]
# iter=4520    weight=[8.391]    bias=[-30.361]    cost=[47.612]
# iter=4530    weight=[8.394]    bias=[-30.381]    cost=[47.61]
# iter=4540    weight=[8.397]    bias=[-30.4]    cost=[47.608]
# iter=4550    weight=[8.4]    bias=[-30.419]    cost=[47.607]
# iter=4560    weight=[8.403]    bias=[-30.438]    cost=[47.605]
# iter=4570    weight=[8.406]    bias=[-30.457]    cost=[47.603]
# iter=4580    weight=[8.409]    bias=[-30.475]    cost=[47.601]
# iter=4590    weight=[8.412]    bias=[-30.494]    cost=[47.599]
# iter=4600    weight=[8.415]    bias=[-30.513]    cost=[47.598]
# iter=4610    weight=[8.418]    bias=[-30.531]    cost=[47.596]
# iter=4620    weight=[8.421]    bias=[-30.55]    cost=[47.594]
# iter=4630    weight=[8.424]    bias=[-30.568]    cost=[47.592]
# iter=4640    weight=[8.427]    bias=[-30.586]    cost=[47.591]
# iter=4650    weight=[8.43]    bias=[-30.604]    cost=[47.589]
# iter=4660    weight=[8.433]    bias=[-30.622]    cost=[47.587]
# iter=4670    weight=[8.435]    bias=[-30.64]    cost=[47.586]
# iter=4680    weight=[8.438]    bias=[-30.658]    cost=[47.584]
# iter=4690    weight=[8.441]    bias=[-30.676]    cost=[47.582]
# iter=4700    weight=[8.444]    bias=[-30.694]    cost=[47.581]
# iter=4710    weight=[8.447]    bias=[-30.712]    cost=[47.579]
# iter=4720    weight=[8.449]    bias=[-30.729]    cost=[47.578]
# iter=4730    weight=[8.452]    bias=[-30.747]    cost=[47.576]
# iter=4740    weight=[8.455]    bias=[-30.764]    cost=[47.574]
# iter=4750    weight=[8.458]    bias=[-30.781]    cost=[47.573]
# iter=4760    weight=[8.46]    bias=[-30.799]    cost=[47.571]
# iter=4770    weight=[8.463]    bias=[-30.816]    cost=[47.57]
# iter=4780    weight=[8.466]    bias=[-30.833]    cost=[47.568]
# iter=4790    weight=[8.468]    bias=[-30.85]    cost=[47.567]
# iter=4800    weight=[8.471]    bias=[-30.867]    cost=[47.565]
# iter=4810    weight=[8.474]    bias=[-30.883]    cost=[47.564]
# iter=4820    weight=[8.476]    bias=[-30.9]    cost=[47.563]
# iter=4830    weight=[8.479]    bias=[-30.917]    cost=[47.561]
# iter=4840    weight=[8.482]    bias=[-30.933]    cost=[47.56]
# iter=4850    weight=[8.484]    bias=[-30.95]    cost=[47.558]
# iter=4860    weight=[8.487]    bias=[-30.966]    cost=[47.557]
# iter=4870    weight=[8.489]    bias=[-30.983]    cost=[47.556]
# iter=4880    weight=[8.492]    bias=[-30.999]    cost=[47.554]
# iter=4890    weight=[8.494]    bias=[-31.015]    cost=[47.553]
# iter=4900    weight=[8.497]    bias=[-31.031]    cost=[47.552]
# iter=4910    weight=[8.5]    bias=[-31.047]    cost=[47.55]
# iter=4920    weight=[8.502]    bias=[-31.063]    cost=[47.549]
# iter=4930    weight=[8.505]    bias=[-31.079]    cost=[47.548]
# iter=4940    weight=[8.507]    bias=[-31.095]    cost=[47.546]
# iter=4950    weight=[8.51]    bias=[-31.111]    cost=[47.545]
# iter=4960    weight=[8.512]    bias=[-31.126]    cost=[47.544]
# iter=4970    weight=[8.514]    bias=[-31.142]    cost=[47.543]
# iter=4980    weight=[8.517]    bias=[-31.158]    cost=[47.541]
# iter=4990    weight=[8.519]    bias=[-31.173]    cost=[47.54]
# iter=5000    weight=[8.522]    bias=[-31.188]    cost=[47.539]
# iter=5010    weight=[8.524]    bias=[-31.204]    cost=[47.538]
# iter=5020    weight=[8.527]    bias=[-31.219]    cost=[47.537]
# iter=5030    weight=[8.529]    bias=[-31.234]    cost=[47.535]
# iter=5040    weight=[8.531]    bias=[-31.249]    cost=[47.534]
# iter=5050    weight=[8.534]    bias=[-31.264]    cost=[47.533]
# iter=5060    weight=[8.536]    bias=[-31.279]    cost=[47.532]
# iter=5070    weight=[8.538]    bias=[-31.294]    cost=[47.531]
# iter=5080    weight=[8.541]    bias=[-31.309]    cost=[47.53]
# iter=5090    weight=[8.543]    bias=[-31.323]    cost=[47.529]
# iter=5100    weight=[8.545]    bias=[-31.338]    cost=[47.527]
# iter=5110    weight=[8.548]    bias=[-31.353]    cost=[47.526]
# iter=5120    weight=[8.55]    bias=[-31.367]    cost=[47.525]
# iter=5130    weight=[8.552]    bias=[-31.382]    cost=[47.524]
# iter=5140    weight=[8.554]    bias=[-31.396]    cost=[47.523]
# iter=5150    weight=[8.557]    bias=[-31.41]    cost=[47.522]
# iter=5160    weight=[8.559]    bias=[-31.425]    cost=[47.521]
# iter=5170    weight=[8.561]    bias=[-31.439]    cost=[47.52]
# iter=5180    weight=[8.563]    bias=[-31.453]    cost=[47.519]
# iter=5190    weight=[8.566]    bias=[-31.467]    cost=[47.518]
# iter=5200    weight=[8.568]    bias=[-31.481]    cost=[47.517]
# iter=5210    weight=[8.57]    bias=[-31.495]    cost=[47.516]
# iter=5220    weight=[8.572]    bias=[-31.509]    cost=[47.515]
# iter=5230    weight=[8.574]    bias=[-31.522]    cost=[47.514]
# iter=5240    weight=[8.577]    bias=[-31.536]    cost=[47.513]
# iter=5250    weight=[8.579]    bias=[-31.55]    cost=[47.512]
# iter=5260    weight=[8.581]    bias=[-31.563]    cost=[47.511]
# iter=5270    weight=[8.583]    bias=[-31.577]    cost=[47.51]
# iter=5280    weight=[8.585]    bias=[-31.59]    cost=[47.509]
# iter=5290    weight=[8.587]    bias=[-31.604]    cost=[47.508]
# iter=5300    weight=[8.589]    bias=[-31.617]    cost=[47.508]
# iter=5310    weight=[8.591]    bias=[-31.63]    cost=[47.507]
# iter=5320    weight=[8.593]    bias=[-31.643]    cost=[47.506]
# iter=5330    weight=[8.596]    bias=[-31.656]    cost=[47.505]
# iter=5340    weight=[8.598]    bias=[-31.67]    cost=[47.504]
# iter=5350    weight=[8.6]    bias=[-31.683]    cost=[47.503]
# iter=5360    weight=[8.602]    bias=[-31.695]    cost=[47.502]
# iter=5370    weight=[8.604]    bias=[-31.708]    cost=[47.501]
# iter=5380    weight=[8.606]    bias=[-31.721]    cost=[47.501]
# iter=5390    weight=[8.608]    bias=[-31.734]    cost=[47.5]
# iter=5400    weight=[8.61]    bias=[-31.747]    cost=[47.499]
# iter=5410    weight=[8.612]    bias=[-31.759]    cost=[47.498]
# iter=5420    weight=[8.614]    bias=[-31.772]    cost=[47.497]
# iter=5430    weight=[8.616]    bias=[-31.784]    cost=[47.496]
# iter=5440    weight=[8.618]    bias=[-31.797]    cost=[47.496]
# iter=5450    weight=[8.62]    bias=[-31.809]    cost=[47.495]
# iter=5460    weight=[8.622]    bias=[-31.822]    cost=[47.494]
# iter=5470    weight=[8.623]    bias=[-31.834]    cost=[47.493]
# iter=5480    weight=[8.625]    bias=[-31.846]    cost=[47.493]
# iter=5490    weight=[8.627]    bias=[-31.858]    cost=[47.492]
# iter=5500    weight=[8.629]    bias=[-31.87]    cost=[47.491]
# iter=5510    weight=[8.631]    bias=[-31.882]    cost=[47.49]
# iter=5520    weight=[8.633]    bias=[-31.894]    cost=[47.49]
# iter=5530    weight=[8.635]    bias=[-31.906]    cost=[47.489]
# iter=5540    weight=[8.637]    bias=[-31.918]    cost=[47.488]
# iter=5550    weight=[8.639]    bias=[-31.93]    cost=[47.487]
# iter=5560    weight=[8.64]    bias=[-31.942]    cost=[47.487]
# iter=5570    weight=[8.642]    bias=[-31.953]    cost=[47.486]
# iter=5580    weight=[8.644]    bias=[-31.965]    cost=[47.485]
# iter=5590    weight=[8.646]    bias=[-31.977]    cost=[47.485]
# iter=5600    weight=[8.648]    bias=[-31.988]    cost=[47.484]
# iter=5610    weight=[8.65]    bias=[-32.]    cost=[47.483]
# iter=5620    weight=[8.651]    bias=[-32.011]    cost=[47.483]
# iter=5630    weight=[8.653]    bias=[-32.023]    cost=[47.482]
# iter=5640    weight=[8.655]    bias=[-32.034]    cost=[47.481]
# iter=5650    weight=[8.657]    bias=[-32.045]    cost=[47.481]
# iter=5660    weight=[8.659]    bias=[-32.056]    cost=[47.48]
# iter=5670    weight=[8.66]    bias=[-32.067]    cost=[47.479]
# iter=5680    weight=[8.662]    bias=[-32.079]    cost=[47.479]
# iter=5690    weight=[8.664]    bias=[-32.09]    cost=[47.478]
# iter=5700    weight=[8.666]    bias=[-32.101]    cost=[47.477]
# iter=5710    weight=[8.667]    bias=[-32.112]    cost=[47.477]
# iter=5720    weight=[8.669]    bias=[-32.123]    cost=[47.476]
# iter=5730    weight=[8.671]    bias=[-32.133]    cost=[47.476]
# iter=5740    weight=[8.672]    bias=[-32.144]    cost=[47.475]
# iter=5750    weight=[8.674]    bias=[-32.155]    cost=[47.474]
# iter=5760    weight=[8.676]    bias=[-32.166]    cost=[47.474]
# iter=5770    weight=[8.677]    bias=[-32.176]    cost=[47.473]
# iter=5780    weight=[8.679]    bias=[-32.187]    cost=[47.473]
# iter=5790    weight=[8.681]    bias=[-32.197]    cost=[47.472]
# iter=5800    weight=[8.682]    bias=[-32.208]    cost=[47.472]
# iter=5810    weight=[8.684]    bias=[-32.218]    cost=[47.471]
# iter=5820    weight=[8.686]    bias=[-32.229]    cost=[47.47]
# iter=5830    weight=[8.687]    bias=[-32.239]    cost=[47.47]
# iter=5840    weight=[8.689]    bias=[-32.249]    cost=[47.469]
# iter=5850    weight=[8.691]    bias=[-32.26]    cost=[47.469]
# iter=5860    weight=[8.692]    bias=[-32.27]    cost=[47.468]
# iter=5870    weight=[8.694]    bias=[-32.28]    cost=[47.468]
# iter=5880    weight=[8.695]    bias=[-32.29]    cost=[47.467]
# iter=5890    weight=[8.697]    bias=[-32.3]    cost=[47.467]
# iter=5900    weight=[8.699]    bias=[-32.31]    cost=[47.466]
# iter=5910    weight=[8.7]    bias=[-32.32]    cost=[47.466]
# iter=5920    weight=[8.702]    bias=[-32.33]    cost=[47.465]
# iter=5930    weight=[8.703]    bias=[-32.34]    cost=[47.465]
# iter=5940    weight=[8.705]    bias=[-32.35]    cost=[47.464]
# iter=5950    weight=[8.706]    bias=[-32.359]    cost=[47.464]
# iter=5960    weight=[8.708]    bias=[-32.369]    cost=[47.463]
# iter=5970    weight=[8.709]    bias=[-32.379]    cost=[47.463]
# iter=5980    weight=[8.711]    bias=[-32.388]    cost=[47.462]
# iter=5990    weight=[8.712]    bias=[-32.398]    cost=[47.462]
# iter=6000    weight=[8.714]    bias=[-32.407]    cost=[47.461]
# iter=6010    weight=[8.715]    bias=[-32.417]    cost=[47.461]
# iter=6020    weight=[8.717]    bias=[-32.426]    cost=[47.46]
# iter=6030    weight=[8.718]    bias=[-32.436]    cost=[47.46]
# iter=6040    weight=[8.72]    bias=[-32.445]    cost=[47.46]
# iter=6050    weight=[8.721]    bias=[-32.454]    cost=[47.459]
# iter=6060    weight=[8.723]    bias=[-32.464]    cost=[47.459]
# iter=6070    weight=[8.724]    bias=[-32.473]    cost=[47.458]
# iter=6080    weight=[8.726]    bias=[-32.482]    cost=[47.458]
# iter=6090    weight=[8.727]    bias=[-32.491]    cost=[47.457]
# iter=6100    weight=[8.729]    bias=[-32.5]    cost=[47.457]
# iter=6110    weight=[8.73]    bias=[-32.509]    cost=[47.456]
# iter=6120    weight=[8.731]    bias=[-32.518]    cost=[47.456]
# iter=6130    weight=[8.733]    bias=[-32.527]    cost=[47.456]
# iter=6140    weight=[8.734]    bias=[-32.536]    cost=[47.455]
# iter=6150    weight=[8.736]    bias=[-32.545]    cost=[47.455]
# iter=6160    weight=[8.737]    bias=[-32.554]    cost=[47.454]
# iter=6170    weight=[8.738]    bias=[-32.563]    cost=[47.454]
# iter=6180    weight=[8.74]    bias=[-32.571]    cost=[47.454]
# iter=6190    weight=[8.741]    bias=[-32.58]    cost=[47.453]
# iter=6200    weight=[8.742]    bias=[-32.589]    cost=[47.453]
# iter=6210    weight=[8.744]    bias=[-32.597]    cost=[47.453]
# iter=6220    weight=[8.745]    bias=[-32.606]    cost=[47.452]
# iter=6230    weight=[8.747]    bias=[-32.615]    cost=[47.452]
# iter=6240    weight=[8.748]    bias=[-32.623]    cost=[47.451]
# iter=6250    weight=[8.749]    bias=[-32.632]    cost=[47.451]
# iter=6260    weight=[8.751]    bias=[-32.64]    cost=[47.451]
# iter=6270    weight=[8.752]    bias=[-32.648]    cost=[47.45]
# iter=6280    weight=[8.753]    bias=[-32.657]    cost=[47.45]
# iter=6290    weight=[8.754]    bias=[-32.665]    cost=[47.45]
# iter=6300    weight=[8.756]    bias=[-32.673]    cost=[47.449]
# iter=6310    weight=[8.757]    bias=[-32.682]    cost=[47.449]
# iter=6320    weight=[8.758]    bias=[-32.69]    cost=[47.449]
# iter=6330    weight=[8.76]    bias=[-32.698]    cost=[47.448]
# iter=6340    weight=[8.761]    bias=[-32.706]    cost=[47.448]
# iter=6350    weight=[8.762]    bias=[-32.714]    cost=[47.448]
# iter=6360    weight=[8.763]    bias=[-32.722]    cost=[47.447]
# iter=6370    weight=[8.765]    bias=[-32.73]    cost=[47.447]
# iter=6380    weight=[8.766]    bias=[-32.738]    cost=[47.447]
# iter=6390    weight=[8.767]    bias=[-32.746]    cost=[47.446]
# iter=6400    weight=[8.768]    bias=[-32.754]    cost=[47.446]
# iter=6410    weight=[8.77]    bias=[-32.762]    cost=[47.446]
# iter=6420    weight=[8.771]    bias=[-32.769]    cost=[47.445]
# iter=6430    weight=[8.772]    bias=[-32.777]    cost=[47.445]
# iter=6440    weight=[8.773]    bias=[-32.785]    cost=[47.445]
# iter=6450    weight=[8.775]    bias=[-32.793]    cost=[47.444]
# iter=6460    weight=[8.776]    bias=[-32.8]    cost=[47.444]
# iter=6470    weight=[8.777]    bias=[-32.808]    cost=[47.444]
# iter=6480    weight=[8.778]    bias=[-32.815]    cost=[47.443]
# iter=6490    weight=[8.779]    bias=[-32.823]    cost=[47.443]
# iter=6500    weight=[8.781]    bias=[-32.831]    cost=[47.443]
# iter=6510    weight=[8.782]    bias=[-32.838]    cost=[47.443]
# iter=6520    weight=[8.783]    bias=[-32.845]    cost=[47.442]
# iter=6530    weight=[8.784]    bias=[-32.853]    cost=[47.442]
# iter=6540    weight=[8.785]    bias=[-32.86]    cost=[47.442]
# iter=6550    weight=[8.786]    bias=[-32.868]    cost=[47.442]
# iter=6560    weight=[8.788]    bias=[-32.875]    cost=[47.441]
# iter=6570    weight=[8.789]    bias=[-32.882]    cost=[47.441]
# iter=6580    weight=[8.79]    bias=[-32.889]    cost=[47.441]
# iter=6590    weight=[8.791]    bias=[-32.897]    cost=[47.44]
# iter=6600    weight=[8.792]    bias=[-32.904]    cost=[47.44]
# iter=6610    weight=[8.793]    bias=[-32.911]    cost=[47.44]
# iter=6620    weight=[8.794]    bias=[-32.918]    cost=[47.44]
# iter=6630    weight=[8.795]    bias=[-32.925]    cost=[47.439]
# iter=6640    weight=[8.797]    bias=[-32.932]    cost=[47.439]
# iter=6650    weight=[8.798]    bias=[-32.939]    cost=[47.439]
# iter=6660    weight=[8.799]    bias=[-32.946]    cost=[47.439]
# iter=6670    weight=[8.8]    bias=[-32.953]    cost=[47.438]
# iter=6680    weight=[8.801]    bias=[-32.96]    cost=[47.438]
# iter=6690    weight=[8.802]    bias=[-32.967]    cost=[47.438]
# iter=6700    weight=[8.803]    bias=[-32.973]    cost=[47.438]
# iter=6710    weight=[8.804]    bias=[-32.98]    cost=[47.437]
# iter=6720    weight=[8.805]    bias=[-32.987]    cost=[47.437]
# iter=6730    weight=[8.806]    bias=[-32.994]    cost=[47.437]
# iter=6740    weight=[8.807]    bias=[-33.]    cost=[47.437]
# iter=6750    weight=[8.808]    bias=[-33.007]    cost=[47.437]
# iter=6760    weight=[8.809]    bias=[-33.014]    cost=[47.436]
# iter=6770    weight=[8.81]    bias=[-33.02]    cost=[47.436]
# iter=6780    weight=[8.811]    bias=[-33.027]    cost=[47.436]
# iter=6790    weight=[8.813]    bias=[-33.033]    cost=[47.436]
# iter=6800    weight=[8.814]    bias=[-33.04]    cost=[47.435]
# iter=6810    weight=[8.815]    bias=[-33.046]    cost=[47.435]
# iter=6820    weight=[8.816]    bias=[-33.053]    cost=[47.435]
# iter=6830    weight=[8.817]    bias=[-33.059]    cost=[47.435]
# iter=6840    weight=[8.818]    bias=[-33.066]    cost=[47.435]
# iter=6850    weight=[8.819]    bias=[-33.072]    cost=[47.434]
# iter=6860    weight=[8.82]    bias=[-33.078]    cost=[47.434]
# iter=6870    weight=[8.821]    bias=[-33.085]    cost=[47.434]
# iter=6880    weight=[8.822]    bias=[-33.091]    cost=[47.434]
# iter=6890    weight=[8.823]    bias=[-33.097]    cost=[47.434]
# iter=6900    weight=[8.824]    bias=[-33.103]    cost=[47.433]
# iter=6910    weight=[8.825]    bias=[-33.109]    cost=[47.433]
# iter=6920    weight=[8.825]    bias=[-33.116]    cost=[47.433]
# iter=6930    weight=[8.826]    bias=[-33.122]    cost=[47.433]
# iter=6940    weight=[8.827]    bias=[-33.128]    cost=[47.433]
# iter=6950    weight=[8.828]    bias=[-33.134]    cost=[47.432]
# iter=6960    weight=[8.829]    bias=[-33.14]    cost=[47.432]
# iter=6970    weight=[8.83]    bias=[-33.146]    cost=[47.432]
# iter=6980    weight=[8.831]    bias=[-33.152]    cost=[47.432]
# iter=6990    weight=[8.832]    bias=[-33.158]    cost=[47.432]
# iter=7000    weight=[8.833]    bias=[-33.164]    cost=[47.431]
# iter=7010    weight=[8.834]    bias=[-33.17]    cost=[47.431]
# iter=7020    weight=[8.835]    bias=[-33.176]    cost=[47.431]
# iter=7030    weight=[8.836]    bias=[-33.181]    cost=[47.431]
# iter=7040    weight=[8.837]    bias=[-33.187]    cost=[47.431]
# iter=7050    weight=[8.838]    bias=[-33.193]    cost=[47.431]
# iter=7060    weight=[8.839]    bias=[-33.199]    cost=[47.43]
# iter=7070    weight=[8.839]    bias=[-33.204]    cost=[47.43]
# iter=7080    weight=[8.84]    bias=[-33.21]    cost=[47.43]
# iter=7090    weight=[8.841]    bias=[-33.216]    cost=[47.43]
# iter=7100    weight=[8.842]    bias=[-33.221]    cost=[47.43]
# iter=7110    weight=[8.843]    bias=[-33.227]    cost=[47.43]
# iter=7120    weight=[8.844]    bias=[-33.233]    cost=[47.429]
# iter=7130    weight=[8.845]    bias=[-33.238]    cost=[47.429]
# iter=7140    weight=[8.846]    bias=[-33.244]    cost=[47.429]
# iter=7150    weight=[8.847]    bias=[-33.249]    cost=[47.429]
# iter=7160    weight=[8.847]    bias=[-33.255]    cost=[47.429]
# iter=7170    weight=[8.848]    bias=[-33.26]    cost=[47.429]
# iter=7180    weight=[8.849]    bias=[-33.266]    cost=[47.429]
# iter=7190    weight=[8.85]    bias=[-33.271]    cost=[47.428]
# iter=7200    weight=[8.851]    bias=[-33.276]    cost=[47.428]
# iter=7210    weight=[8.852]    bias=[-33.282]    cost=[47.428]
# iter=7220    weight=[8.852]    bias=[-33.287]    cost=[47.428]
# iter=7230    weight=[8.853]    bias=[-33.292]    cost=[47.428]
# iter=7240    weight=[8.854]    bias=[-33.298]    cost=[47.428]
# iter=7250    weight=[8.855]    bias=[-33.303]    cost=[47.428]
# iter=7260    weight=[8.856]    bias=[-33.308]    cost=[47.427]
# iter=7270    weight=[8.857]    bias=[-33.313]    cost=[47.427]
# iter=7280    weight=[8.857]    bias=[-33.318]    cost=[47.427]
# iter=7290    weight=[8.858]    bias=[-33.324]    cost=[47.427]
# iter=7300    weight=[8.859]    bias=[-33.329]    cost=[47.427]
# iter=7310    weight=[8.86]    bias=[-33.334]    cost=[47.427]
# iter=7320    weight=[8.861]    bias=[-33.339]    cost=[47.427]
# iter=7330    weight=[8.861]    bias=[-33.344]    cost=[47.426]
# iter=7340    weight=[8.862]    bias=[-33.349]    cost=[47.426]
# iter=7350    weight=[8.863]    bias=[-33.354]    cost=[47.426]
# iter=7360    weight=[8.864]    bias=[-33.359]    cost=[47.426]
# iter=7370    weight=[8.865]    bias=[-33.364]    cost=[47.426]
# iter=7380    weight=[8.865]    bias=[-33.369]    cost=[47.426]
# iter=7390    weight=[8.866]    bias=[-33.374]    cost=[47.426]
# iter=7400    weight=[8.867]    bias=[-33.379]    cost=[47.426]
# iter=7410    weight=[8.868]    bias=[-33.384]    cost=[47.425]
# iter=7420    weight=[8.868]    bias=[-33.388]    cost=[47.425]
# iter=7430    weight=[8.869]    bias=[-33.393]    cost=[47.425]
# iter=7440    weight=[8.87]    bias=[-33.398]    cost=[47.425]
# iter=7450    weight=[8.871]    bias=[-33.403]    cost=[47.425]
# iter=7460    weight=[8.871]    bias=[-33.407]    cost=[47.425]
# iter=7470    weight=[8.872]    bias=[-33.412]    cost=[47.425]
# iter=7480    weight=[8.873]    bias=[-33.417]    cost=[47.425]
# iter=7490    weight=[8.874]    bias=[-33.422]    cost=[47.424]
# iter=7500    weight=[8.874]    bias=[-33.426]    cost=[47.424]
# iter=7510    weight=[8.875]    bias=[-33.431]    cost=[47.424]
# iter=7520    weight=[8.876]    bias=[-33.435]    cost=[47.424]
# iter=7530    weight=[8.877]    bias=[-33.44]    cost=[47.424]
# iter=7540    weight=[8.877]    bias=[-33.445]    cost=[47.424]
# iter=7550    weight=[8.878]    bias=[-33.449]    cost=[47.424]
# iter=7560    weight=[8.879]    bias=[-33.454]    cost=[47.424]
# iter=7570    weight=[8.879]    bias=[-33.458]    cost=[47.424]
# iter=7580    weight=[8.88]    bias=[-33.463]    cost=[47.424]
# iter=7590    weight=[8.881]    bias=[-33.467]    cost=[47.423]
# iter=7600    weight=[8.882]    bias=[-33.472]    cost=[47.423]
# iter=7610    weight=[8.882]    bias=[-33.476]    cost=[47.423]
# iter=7620    weight=[8.883]    bias=[-33.48]    cost=[47.423]
# iter=7630    weight=[8.884]    bias=[-33.485]    cost=[47.423]
# iter=7640    weight=[8.884]    bias=[-33.489]    cost=[47.423]
# iter=7650    weight=[8.885]    bias=[-33.494]    cost=[47.423]
# iter=7660    weight=[8.886]    bias=[-33.498]    cost=[47.423]
# iter=7670    weight=[8.886]    bias=[-33.502]    cost=[47.423]
# iter=7680    weight=[8.887]    bias=[-33.506]    cost=[47.423]
# iter=7690    weight=[8.888]    bias=[-33.511]    cost=[47.422]
# iter=7700    weight=[8.888]    bias=[-33.515]    cost=[47.422]
# iter=7710    weight=[8.889]    bias=[-33.519]    cost=[47.422]
# iter=7720    weight=[8.89]    bias=[-33.523]    cost=[47.422]
# iter=7730    weight=[8.89]    bias=[-33.527]    cost=[47.422]
# iter=7740    weight=[8.891]    bias=[-33.532]    cost=[47.422]
# iter=7750    weight=[8.892]    bias=[-33.536]    cost=[47.422]
# iter=7760    weight=[8.892]    bias=[-33.54]    cost=[47.422]
# iter=7770    weight=[8.893]    bias=[-33.544]    cost=[47.422]
# iter=7780    weight=[8.894]    bias=[-33.548]    cost=[47.422]
# iter=7790    weight=[8.894]    bias=[-33.552]    cost=[47.422]
# iter=7800    weight=[8.895]    bias=[-33.556]    cost=[47.422]
# iter=7810    weight=[8.896]    bias=[-33.56]    cost=[47.421]
# iter=7820    weight=[8.896]    bias=[-33.564]    cost=[47.421]
# iter=7830    weight=[8.897]    bias=[-33.568]    cost=[47.421]
# iter=7840    weight=[8.897]    bias=[-33.572]    cost=[47.421]
# iter=7850    weight=[8.898]    bias=[-33.576]    cost=[47.421]
# iter=7860    weight=[8.899]    bias=[-33.58]    cost=[47.421]
# iter=7870    weight=[8.899]    bias=[-33.584]    cost=[47.421]
# iter=7880    weight=[8.9]    bias=[-33.588]    cost=[47.421]
# iter=7890    weight=[8.9]    bias=[-33.592]    cost=[47.421]
# iter=7900    weight=[8.901]    bias=[-33.595]    cost=[47.421]
# iter=7910    weight=[8.902]    bias=[-33.599]    cost=[47.421]
# iter=7920    weight=[8.902]    bias=[-33.603]    cost=[47.421]
# iter=7930    weight=[8.903]    bias=[-33.607]    cost=[47.42]
# iter=7940    weight=[8.904]    bias=[-33.611]    cost=[47.42]
# iter=7950    weight=[8.904]    bias=[-33.614]    cost=[47.42]
# iter=7960    weight=[8.905]    bias=[-33.618]    cost=[47.42]
# iter=7970    weight=[8.905]    bias=[-33.622]    cost=[47.42]
# iter=7980    weight=[8.906]    bias=[-33.626]    cost=[47.42]
# iter=7990    weight=[8.906]    bias=[-33.629]    cost=[47.42]
# iter=8000    weight=[8.907]    bias=[-33.633]    cost=[47.42]
# iter=8010    weight=[8.908]    bias=[-33.637]    cost=[47.42]
# iter=8020    weight=[8.908]    bias=[-33.64]    cost=[47.42]
# iter=8030    weight=[8.909]    bias=[-33.644]    cost=[47.42]
# iter=8040    weight=[8.909]    bias=[-33.648]    cost=[47.42]
# iter=8050    weight=[8.91]    bias=[-33.651]    cost=[47.42]
# iter=8060    weight=[8.91]    bias=[-33.655]    cost=[47.42]
# iter=8070    weight=[8.911]    bias=[-33.658]    cost=[47.42]
# iter=8080    weight=[8.912]    bias=[-33.662]    cost=[47.419]
# iter=8090    weight=[8.912]    bias=[-33.665]    cost=[47.419]
# iter=8100    weight=[8.913]    bias=[-33.669]    cost=[47.419]
# iter=8110    weight=[8.913]    bias=[-33.672]    cost=[47.419]
# iter=8120    weight=[8.914]    bias=[-33.676]    cost=[47.419]
# iter=8130    weight=[8.914]    bias=[-33.679]    cost=[47.419]
# iter=8140    weight=[8.915]    bias=[-33.683]    cost=[47.419]
# iter=8150    weight=[8.915]    bias=[-33.686]    cost=[47.419]
# iter=8160    weight=[8.916]    bias=[-33.689]    cost=[47.419]
# iter=8170    weight=[8.916]    bias=[-33.693]    cost=[47.419]
# iter=8180    weight=[8.917]    bias=[-33.696]    cost=[47.419]
# iter=8190    weight=[8.917]    bias=[-33.699]    cost=[47.419]
# iter=8200    weight=[8.918]    bias=[-33.703]    cost=[47.419]
# iter=8210    weight=[8.919]    bias=[-33.706]    cost=[47.419]
# iter=8220    weight=[8.919]    bias=[-33.709]    cost=[47.419]
# iter=8230    weight=[8.92]    bias=[-33.713]    cost=[47.419]
# iter=8240    weight=[8.92]    bias=[-33.716]    cost=[47.419]
# iter=8250    weight=[8.921]    bias=[-33.719]    cost=[47.418]
# iter=8260    weight=[8.921]    bias=[-33.723]    cost=[47.418]
# iter=8270    weight=[8.922]    bias=[-33.726]    cost=[47.418]
# iter=8280    weight=[8.922]    bias=[-33.729]    cost=[47.418]
# iter=8290    weight=[8.923]    bias=[-33.732]    cost=[47.418]
# iter=8300    weight=[8.923]    bias=[-33.735]    cost=[47.418]
# iter=8310    weight=[8.924]    bias=[-33.738]    cost=[47.418]
# iter=8320    weight=[8.924]    bias=[-33.742]    cost=[47.418]
# iter=8330    weight=[8.925]    bias=[-33.745]    cost=[47.418]
# iter=8340    weight=[8.925]    bias=[-33.748]    cost=[47.418]
# iter=8350    weight=[8.926]    bias=[-33.751]    cost=[47.418]
# iter=8360    weight=[8.926]    bias=[-33.754]    cost=[47.418]
# iter=8370    weight=[8.927]    bias=[-33.757]    cost=[47.418]
# iter=8380    weight=[8.927]    bias=[-33.76]    cost=[47.418]
# iter=8390    weight=[8.928]    bias=[-33.763]    cost=[47.418]
# iter=8400    weight=[8.928]    bias=[-33.766]    cost=[47.418]
# iter=8410    weight=[8.928]    bias=[-33.769]    cost=[47.418]
# iter=8420    weight=[8.929]    bias=[-33.772]    cost=[47.418]
# iter=8430    weight=[8.929]    bias=[-33.775]    cost=[47.418]
# iter=8440    weight=[8.93]    bias=[-33.778]    cost=[47.418]
# iter=8450    weight=[8.93]    bias=[-33.781]    cost=[47.417]
# iter=8460    weight=[8.931]    bias=[-33.784]    cost=[47.417]
# iter=8470    weight=[8.931]    bias=[-33.787]    cost=[47.417]
# iter=8480    weight=[8.932]    bias=[-33.79]    cost=[47.417]
# iter=8490    weight=[8.932]    bias=[-33.793]    cost=[47.417]
# iter=8500    weight=[8.933]    bias=[-33.796]    cost=[47.417]
# iter=8510    weight=[8.933]    bias=[-33.799]    cost=[47.417]
# iter=8520    weight=[8.934]    bias=[-33.802]    cost=[47.417]
# iter=8530    weight=[8.934]    bias=[-33.804]    cost=[47.417]
# iter=8540    weight=[8.934]    bias=[-33.807]    cost=[47.417]
# iter=8550    weight=[8.935]    bias=[-33.81]    cost=[47.417]
# iter=8560    weight=[8.935]    bias=[-33.813]    cost=[47.417]
# iter=8570    weight=[8.936]    bias=[-33.816]    cost=[47.417]
# iter=8580    weight=[8.936]    bias=[-33.818]    cost=[47.417]
# iter=8590    weight=[8.937]    bias=[-33.821]    cost=[47.417]
# iter=8600    weight=[8.937]    bias=[-33.824]    cost=[47.417]
# iter=8610    weight=[8.938]    bias=[-33.827]    cost=[47.417]
# iter=8620    weight=[8.938]    bias=[-33.829]    cost=[47.417]
# iter=8630    weight=[8.938]    bias=[-33.832]    cost=[47.417]
# iter=8640    weight=[8.939]    bias=[-33.835]    cost=[47.417]
# iter=8650    weight=[8.939]    bias=[-33.838]    cost=[47.417]
# iter=8660    weight=[8.94]    bias=[-33.84]    cost=[47.417]
# iter=8670    weight=[8.94]    bias=[-33.843]    cost=[47.417]
# iter=8680    weight=[8.941]    bias=[-33.846]    cost=[47.417]
# iter=8690    weight=[8.941]    bias=[-33.848]    cost=[47.417]
# iter=8700    weight=[8.941]    bias=[-33.851]    cost=[47.416]
# iter=8710    weight=[8.942]    bias=[-33.853]    cost=[47.416]
# iter=8720    weight=[8.942]    bias=[-33.856]    cost=[47.416]
# iter=8730    weight=[8.943]    bias=[-33.859]    cost=[47.416]
# iter=8740    weight=[8.943]    bias=[-33.861]    cost=[47.416]
# iter=8750    weight=[8.943]    bias=[-33.864]    cost=[47.416]
# iter=8760    weight=[8.944]    bias=[-33.866]    cost=[47.416]
# iter=8770    weight=[8.944]    bias=[-33.869]    cost=[47.416]
# iter=8780    weight=[8.945]    bias=[-33.871]    cost=[47.416]
# iter=8790    weight=[8.945]    bias=[-33.874]    cost=[47.416]
# iter=8800    weight=[8.945]    bias=[-33.876]    cost=[47.416]
# iter=8810    weight=[8.946]    bias=[-33.879]    cost=[47.416]
# iter=8820    weight=[8.946]    bias=[-33.881]    cost=[47.416]
# iter=8830    weight=[8.947]    bias=[-33.884]    cost=[47.416]
# iter=8840    weight=[8.947]    bias=[-33.886]    cost=[47.416]
# iter=8850    weight=[8.947]    bias=[-33.889]    cost=[47.416]
# iter=8860    weight=[8.948]    bias=[-33.891]    cost=[47.416]
# iter=8870    weight=[8.948]    bias=[-33.894]    cost=[47.416]
# iter=8880    weight=[8.948]    bias=[-33.896]    cost=[47.416]
# iter=8890    weight=[8.949]    bias=[-33.898]    cost=[47.416]
# iter=8900    weight=[8.949]    bias=[-33.901]    cost=[47.416]
# iter=8910    weight=[8.95]    bias=[-33.903]    cost=[47.416]
# iter=8920    weight=[8.95]    bias=[-33.906]    cost=[47.416]
# iter=8930    weight=[8.95]    bias=[-33.908]    cost=[47.416]
# iter=8940    weight=[8.951]    bias=[-33.91]    cost=[47.416]
# iter=8950    weight=[8.951]    bias=[-33.913]    cost=[47.416]
# iter=8960    weight=[8.951]    bias=[-33.915]    cost=[47.416]
# iter=8970    weight=[8.952]    bias=[-33.917]    cost=[47.416]
# iter=8980    weight=[8.952]    bias=[-33.92]    cost=[47.416]
# iter=8990    weight=[8.953]    bias=[-33.922]    cost=[47.416]
# iter=9000    weight=[8.953]    bias=[-33.924]    cost=[47.416]
# iter=9010    weight=[8.953]    bias=[-33.926]    cost=[47.416]
# iter=9020    weight=[8.954]    bias=[-33.929]    cost=[47.416]
# iter=9030    weight=[8.954]    bias=[-33.931]    cost=[47.415]
# iter=9040    weight=[8.954]    bias=[-33.933]    cost=[47.415]
# iter=9050    weight=[8.955]    bias=[-33.935]    cost=[47.415]
# iter=9060    weight=[8.955]    bias=[-33.938]    cost=[47.415]
# iter=9070    weight=[8.955]    bias=[-33.94]    cost=[47.415]
# iter=9080    weight=[8.956]    bias=[-33.942]    cost=[47.415]
# iter=9090    weight=[8.956]    bias=[-33.944]    cost=[47.415]
# iter=9100    weight=[8.956]    bias=[-33.946]    cost=[47.415]
# iter=9110    weight=[8.957]    bias=[-33.948]    cost=[47.415]
# iter=9120    weight=[8.957]    bias=[-33.951]    cost=[47.415]
# iter=9130    weight=[8.957]    bias=[-33.953]    cost=[47.415]
# iter=9140    weight=[8.958]    bias=[-33.955]    cost=[47.415]
# iter=9150    weight=[8.958]    bias=[-33.957]    cost=[47.415]
# iter=9160    weight=[8.958]    bias=[-33.959]    cost=[47.415]
# iter=9170    weight=[8.959]    bias=[-33.961]    cost=[47.415]
# iter=9180    weight=[8.959]    bias=[-33.963]    cost=[47.415]
# iter=9190    weight=[8.959]    bias=[-33.965]    cost=[47.415]
# iter=9200    weight=[8.96]    bias=[-33.967]    cost=[47.415]
# iter=9210    weight=[8.96]    bias=[-33.97]    cost=[47.415]
# iter=9220    weight=[8.96]    bias=[-33.972]    cost=[47.415]
# iter=9230    weight=[8.961]    bias=[-33.974]    cost=[47.415]
# iter=9240    weight=[8.961]    bias=[-33.976]    cost=[47.415]
# iter=9250    weight=[8.961]    bias=[-33.978]    cost=[47.415]
# iter=9260    weight=[8.962]    bias=[-33.98]    cost=[47.415]
# iter=9270    weight=[8.962]    bias=[-33.982]    cost=[47.415]
# iter=9280    weight=[8.962]    bias=[-33.984]    cost=[47.415]
# iter=9290    weight=[8.963]    bias=[-33.986]    cost=[47.415]
# iter=9300    weight=[8.963]    bias=[-33.988]    cost=[47.415]
# iter=9310    weight=[8.963]    bias=[-33.99]    cost=[47.415]
# iter=9320    weight=[8.964]    bias=[-33.992]    cost=[47.415]
# iter=9330    weight=[8.964]    bias=[-33.993]    cost=[47.415]
# iter=9340    weight=[8.964]    bias=[-33.995]    cost=[47.415]
# iter=9350    weight=[8.964]    bias=[-33.997]    cost=[47.415]
# iter=9360    weight=[8.965]    bias=[-33.999]    cost=[47.415]
# iter=9370    weight=[8.965]    bias=[-34.001]    cost=[47.415]
# iter=9380    weight=[8.965]    bias=[-34.003]    cost=[47.415]
# iter=9390    weight=[8.966]    bias=[-34.005]    cost=[47.415]
# iter=9400    weight=[8.966]    bias=[-34.007]    cost=[47.415]
# iter=9410    weight=[8.966]    bias=[-34.009]    cost=[47.415]
# iter=9420    weight=[8.967]    bias=[-34.011]    cost=[47.415]
# iter=9430    weight=[8.967]    bias=[-34.012]    cost=[47.415]
# iter=9440    weight=[8.967]    bias=[-34.014]    cost=[47.415]
# iter=9450    weight=[8.967]    bias=[-34.016]    cost=[47.415]
# iter=9460    weight=[8.968]    bias=[-34.018]    cost=[47.415]
# iter=9470    weight=[8.968]    bias=[-34.02]    cost=[47.415]
# iter=9480    weight=[8.968]    bias=[-34.022]    cost=[47.415]
# iter=9490    weight=[8.969]    bias=[-34.023]    cost=[47.415]
# iter=9500    weight=[8.969]    bias=[-34.025]    cost=[47.415]
# iter=9510    weight=[8.969]    bias=[-34.027]    cost=[47.414]
# iter=9520    weight=[8.969]    bias=[-34.029]    cost=[47.414]
# iter=9530    weight=[8.97]    bias=[-34.03]    cost=[47.414]
# iter=9540    weight=[8.97]    bias=[-34.032]    cost=[47.414]
# iter=9550    weight=[8.97]    bias=[-34.034]    cost=[47.414]
# iter=9560    weight=[8.97]    bias=[-34.036]    cost=[47.414]
# iter=9570    weight=[8.971]    bias=[-34.037]    cost=[47.414]
# iter=9580    weight=[8.971]    bias=[-34.039]    cost=[47.414]
# iter=9590    weight=[8.971]    bias=[-34.041]    cost=[47.414]
# iter=9600    weight=[8.972]    bias=[-34.043]    cost=[47.414]
# iter=9610    weight=[8.972]    bias=[-34.044]    cost=[47.414]
# iter=9620    weight=[8.972]    bias=[-34.046]    cost=[47.414]
# iter=9630    weight=[8.972]    bias=[-34.048]    cost=[47.414]
# iter=9640    weight=[8.973]    bias=[-34.049]    cost=[47.414]
# iter=9650    weight=[8.973]    bias=[-34.051]    cost=[47.414]
# iter=9660    weight=[8.973]    bias=[-34.053]    cost=[47.414]
# iter=9670    weight=[8.973]    bias=[-34.054]    cost=[47.414]
# iter=9680    weight=[8.974]    bias=[-34.056]    cost=[47.414]
# iter=9690    weight=[8.974]    bias=[-34.058]    cost=[47.414]
# iter=9700    weight=[8.974]    bias=[-34.059]    cost=[47.414]
# iter=9710    weight=[8.974]    bias=[-34.061]    cost=[47.414]
# iter=9720    weight=[8.975]    bias=[-34.063]    cost=[47.414]
# iter=9730    weight=[8.975]    bias=[-34.064]    cost=[47.414]
# iter=9740    weight=[8.975]    bias=[-34.066]    cost=[47.414]
# iter=9750    weight=[8.975]    bias=[-34.067]    cost=[47.414]
# iter=9760    weight=[8.976]    bias=[-34.069]    cost=[47.414]
# iter=9770    weight=[8.976]    bias=[-34.07]    cost=[47.414]
# iter=9780    weight=[8.976]    bias=[-34.072]    cost=[47.414]
# iter=9790    weight=[8.976]    bias=[-34.074]    cost=[47.414]
# iter=9800    weight=[8.977]    bias=[-34.075]    cost=[47.414]
# iter=9810    weight=[8.977]    bias=[-34.077]    cost=[47.414]
# iter=9820    weight=[8.977]    bias=[-34.078]    cost=[47.414]
# iter=9830    weight=[8.977]    bias=[-34.08]    cost=[47.414]
# iter=9840    weight=[8.978]    bias=[-34.081]    cost=[47.414]
# iter=9850    weight=[8.978]    bias=[-34.083]    cost=[47.414]
# iter=9860    weight=[8.978]    bias=[-34.084]    cost=[47.414]
# iter=9870    weight=[8.978]    bias=[-34.086]    cost=[47.414]
# iter=9880    weight=[8.979]    bias=[-34.087]    cost=[47.414]
# iter=9890    weight=[8.979]    bias=[-34.089]    cost=[47.414]
# iter=9900    weight=[8.979]    bias=[-34.09]    cost=[47.414]
# iter=9910    weight=[8.979]    bias=[-34.092]    cost=[47.414]
# iter=9920    weight=[8.98]    bias=[-34.093]    cost=[47.414]
# iter=9930    weight=[8.98]    bias=[-34.095]    cost=[47.414]
# iter=9940    weight=[8.98]    bias=[-34.096]    cost=[47.414]
# iter=9950    weight=[8.98]    bias=[-34.098]    cost=[47.414]
# iter=9960    weight=[8.98]    bias=[-34.099]    cost=[47.414]
# iter=9970    weight=[8.981]    bias=[-34.1]    cost=[47.414]
# iter=9980    weight=[8.981]    bias=[-34.102]    cost=[47.414]
# iter=9990    weight=[8.981]    bias=[-34.103]    cost=[47.414]
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(cost_history, '-r', linewidth=3)
plt.title("Cost Function History")
plt.xlabel("Iteration number")
plt.ylabel("Cost Value")
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">
